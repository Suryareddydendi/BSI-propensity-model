# %% [markdown]
# ## Data Preparation/ for Model Training
# ### Steps:
# - First we need to create `Input` folder with 2 subfolders: `BSI_data`, `Public_data`and paste the corresponding files in each folder.
#
#     1. **BSI_data folder:**
#
#         > `one_off_data`
#
#         > `BSI_CREDITREPORTING`
#
#         > `MLW_LOGINS`
#
#     2. **Public_data folder:**
#         > `Census_Demographic`
#
#         > `HPI`
#
#         > `Interest_Rate`
#
#         > `Zip_FIPS_Mapping`
#
# Note: All dataset file names should be name as same.

# %% [markdown]
# #### Install the all Depedencies/Library

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in c:\users\12098\anaconda3.1\lib\site-packages (from -r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\12098\anaconda3.1\lib\site-packages (from -r requirements.txt (line 2)) (3.8.0)
# Requirement already satisfied: seaborn in c:\users\12098\anaconda3.1\lib\site-packages (from -r requirements.txt (line 3)) (0.12.2)
# Collecting catboost (from -r requirements.txt (line 4))
#   Downloading catboost-1.2.7-cp311-cp311-win_amd64.whl.metadata (1.2 kB)
# Requirement already satisfied: imbalanced-learn in c:\users\12098\anaconda3.1\lib\site-packages (from -r requirements.txt (line 5)) (0.11.0)
# Collecting imblearn (from -r requirements.txt (line 6))
#   Downloading imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Collecting lightgbm (from -r requirements.txt (line 7))
#   Downloading lightgbm-4.5.0-py3-none-win_amd64.whl.metadata (17 kB)
# Collecting optbinning (from -r requirements.txt (line 8))
#   Downloading optbinning-0.20.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: pandas in c:\users\12098\anaconda3.1\lib\site-packages (from -r requirements.txt (line 9)) (2.1.4)
# Collecting pandas-profiling (from -r requirements.txt (line 10))
#   Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: plotly in c:\users\12098\anaconda3.1\lib\site-packages (from -r requirements.txt (line 11)) (5.9.0)
# Requirement already satisfied: python-dotenv in c:\users\12098\anaconda3.1\lib\site-packages (from -r requirements.txt (line 12)) (0.21.0)
# Requirement already satisfied: scikit-learn in c:\users\12098\anaconda3.1\lib\site-packages (from -r requirements.txt (line 13)) (1.2.2)
# Requirement already satisfied: scipy in c:\users\12098\anaconda3.1\lib\site-packages (from -r requirements.txt (line 14)) (1.11.4)
# Requirement already satisfied: setuptools in c:\users\12098\anaconda3.1\lib\site-packages (from -r requirements.txt (line 16)) (68.2.2)
# Collecting sqldf (from -r requirements.txt (line 17))
#   Downloading sqldf-0.4.2-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: statsmodels in c:\users\12098\anaconda3.1\lib\site-packages (from -r requirements.txt (line 18)) (0.14.0)
# Requirement already satisfied: tqdm in c:\users\12098\anaconda3.1\lib\site-packages (from -r requirements.txt (line 19)) (4.65.0)
# Collecting xgboost (from -r requirements.txt (line 20))
#   Downloading xgboost-2.1.4-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\12098\anaconda3.1\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\12098\anaconda3.1\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\12098\anaconda3.1\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\12098\anaconda3.1\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\12098\anaconda3.1\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\12098\anaconda3.1\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\12098\anaconda3.1\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\12098\anaconda3.1\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (2.8.2)
# Collecting graphviz (from catboost->-r requirements.txt (line 4))
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: six in c:\users\12098\anaconda3.1\lib\site-packages (from catboost->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\12098\anaconda3.1\lib\site-packages (from imbalanced-learn->-r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\12098\anaconda3.1\lib\site-packages (from imbalanced-learn->-r requirements.txt (line 5)) (2.2.0)
# Collecting ortools>=9.4 (from optbinning->-r requirements.txt (line 8))
#   Downloading ortools-9.11.4210-cp311-cp311-win_amd64.whl.metadata (3.0 kB)
# Collecting ropwr>=1.0.0 (from optbinning->-r requirements.txt (line 8))
#   Downloading ropwr-1.1.0-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\12098\anaconda3.1\lib\site-packages (from pandas->-r requirements.txt (line 9)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\12098\anaconda3.1\lib\site-packages (from pandas->-r requirements.txt (line 9)) (2023.3)
# Collecting joblib>=1.1.1 (from imbalanced-learn->-r requirements.txt (line 5))
#   Downloading joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\12098\anaconda3.1\lib\site-packages (from pandas-profiling->-r requirements.txt (line 10)) (1.10.12)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\12098\anaconda3.1\lib\site-packages (from pandas-profiling->-r requirements.txt (line 10)) (6.0.1)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\12098\anaconda3.1\lib\site-packages (from pandas-profiling->-r requirements.txt (line 10)) (3.1.3)
# Requirement already satisfied: markupsafe~=2.1.1 in c:\users\12098\anaconda3.1\lib\site-packages (from pandas-profiling->-r requirements.txt (line 10)) (2.1.3)
# Collecting visions==0.7.4 (from visions[type_image_path]==0.7.4->pandas-profiling->-r requirements.txt (line 10))
#   Downloading visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# Collecting htmlmin>=0.1.12 (from pandas-profiling->-r requirements.txt (line 10))
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting missingno>=0.4.2 (from pandas-profiling->-r requirements.txt (line 10))
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Collecting phik>=0.11.1 (from pandas-profiling->-r requirements.txt (line 10))
#   Downloading phik-0.12.4-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# Collecting tangled-up-in-unicode==0.2.0 (from pandas-profiling->-r requirements.txt (line 10))
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: requests>=2.24.0 in c:\users\12098\anaconda3.1\lib\site-packages (from pandas-profiling->-r requirements.txt (line 10)) (2.31.0)
# Collecting multimethod>=1.4 (from pandas-profiling->-r requirements.txt (line 10))
#   Downloading multimethod-2.0-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\12098\anaconda3.1\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling->-r requirements.txt (line 10)) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\12098\anaconda3.1\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling->-r requirements.txt (line 10)) (3.1)
# Collecting imagehash (from visions[type_image_path]==0.7.4->pandas-profiling->-r requirements.txt (line 10))
#   Downloading ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\12098\anaconda3.1\lib\site-packages (from plotly->-r requirements.txt (line 11)) (8.2.2)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\12098\anaconda3.1\lib\site-packages (from statsmodels->-r requirements.txt (line 18)) (0.5.3)
# Requirement already satisfied: colorama in c:\users\12098\anaconda3.1\lib\site-packages (from tqdm->-r requirements.txt (line 19)) (0.4.6)
# Requirement already satisfied: absl-py>=2.0.0 in c:\users\12098\anaconda3.1\lib\site-packages (from ortools>=9.4->optbinning->-r requirements.txt (line 8)) (2.1.0)
# Collecting protobuf<5.27,>=5.26.1 (from ortools>=9.4->optbinning->-r requirements.txt (line 8))
#   Downloading protobuf-5.26.1-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting immutabledict>=3.0.0 (from ortools>=9.4->optbinning->-r requirements.txt (line 8))
#   Downloading immutabledict-4.2.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\12098\anaconda3.1\lib\site-packages (from pydantic>=1.8.1->pandas-profiling->-r requirements.txt (line 10)) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\12098\anaconda3.1\lib\site-packages (from requests>=2.24.0->pandas-profiling->-r requirements.txt (line 10)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\12098\anaconda3.1\lib\site-packages (from requests>=2.24.0->pandas-profiling->-r requirements.txt (line 10)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\12098\anaconda3.1\lib\site-packages (from requests>=2.24.0->pandas-profiling->-r requirements.txt (line 10)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\12098\anaconda3.1\lib\site-packages (from requests>=2.24.0->pandas-profiling->-r requirements.txt (line 10)) (2024.2.2)
# Collecting cvxpy>=1.1.14 (from ropwr>=1.0.0->optbinning->-r requirements.txt (line 8))
#   Downloading cvxpy-1.6.0-cp311-cp311-win_amd64.whl.metadata (9.4 kB)
# Collecting osqp>=0.6.2 (from cvxpy>=1.1.14->ropwr>=1.0.0->optbinning->-r requirements.txt (line 8))
#   Downloading osqp-0.6.7.post3-cp311-cp311-win_amd64.whl.metadata (2.0 kB)
# Collecting clarabel>=0.5.0 (from cvxpy>=1.1.14->ropwr>=1.0.0->optbinning->-r requirements.txt (line 8))
#   Downloading clarabel-0.10.0-cp39-abi3-win_amd64.whl.metadata (4.8 kB)
# Collecting scs>=3.2.4.post1 (from cvxpy>=1.1.14->ropwr>=1.0.0->optbinning->-r requirements.txt (line 8))
#   Downloading scs-3.2.7.post2-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: PyWavelets in c:\users\12098\anaconda3.1\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling->-r requirements.txt (line 10)) (1.5.0)
# Collecting qdldl (from osqp>=0.6.2->cvxpy>=1.1.14->ropwr>=1.0.0->optbinning->-r requirements.txt (line 8))
#   Downloading qdldl-0.1.7.post5-cp311-cp311-win_amd64.whl.metadata (1.8 kB)
# Downloading catboost-1.2.7-cp311-cp311-win_amd64.whl (101.7 MB)
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.1/101.7 MB 3.0 MB/s eta 0:00:35
#    ---------------------------------------- 1.0/101.7 MB 12.2 MB/s eta 0:00:09
#    - -------------------------------------- 3.5/101.7 MB 27.9 MB/s eta 0:00:04
#    -- ------------------------------------- 6.3/101.7 MB 36.7 MB/s eta 0:00:03
#    --- ------------------------------------ 7.8/101.7 MB 35.5 MB/s eta 0:00:03
#    --- ------------------------------------ 9.0/101.7 MB 38.4 MB/s eta 0:00:03
#    --- ------------------------------------ 9.0/101.7 MB 28.9 MB/s eta 0:00:04
#    --- ------------------------------------ 9.2/101.7 MB 25.5 MB/s eta 0:00:04
#    --- ------------------------------------ 9.5/101.7 MB 26.4 MB/s eta 0:00:04
#    --- ------------------------------------ 9.8/101.7 MB 21.7 MB/s eta 0:00:05
#    ---- ----------------------------------- 10.5/101.7 MB 23.4 MB/s eta 0:00:04
#    ------ --------------------------------- 16.3/101.7 MB 27.3 MB/s eta 0:00:04
#    ------ --------------------------------- 17.7/101.7 MB 28.5 MB/s eta 0:00:03
#    ------- -------------------------------- 17.9/101.7 MB 23.4 MB/s eta 0:00:04
#    -------- ------------------------------- 20.6/101.7 MB 50.4 MB/s eta 0:00:02
#    --------- ------------------------------ 24.7/101.7 MB 54.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 26.1/101.7 MB 50.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 27.3/101.7 MB 43.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 30.3/101.7 MB 59.5 MB/s eta 0:00:02
#    ------------ --------------------------- 30.8/101.7 MB 43.7 MB/s eta 0:00:02
#    ------------ --------------------------- 32.3/101.7 MB 38.5 MB/s eta 0:00:02
#    ------------- -------------------------- 34.2/101.7 MB 36.4 MB/s eta 0:00:02
#    ------------- -------------------------- 34.7/101.7 MB 31.2 MB/s eta 0:00:03
#    -------------- ------------------------- 36.0/101.7 MB 28.4 MB/s eta 0:00:03
#    -------------- ------------------------- 37.9/101.7 MB 32.8 MB/s eta 0:00:02
#    --------------- ------------------------ 39.5/101.7 MB 31.2 MB/s eta 0:00:02
#    --------------- ------------------------ 40.3/101.7 MB 26.2 MB/s eta 0:00:03
#    ---------------- ----------------------- 43.0/101.7 MB 32.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 44.9/101.7 MB 36.4 MB/s eta 0:00:02
#    ------------------ --------------------- 47.3/101.7 MB 40.9 MB/s eta 0:00:02
#    ------------------- -------------------- 49.7/101.7 MB 43.7 MB/s eta 0:00:02
#    -------------------- ------------------- 51.3/101.7 MB 50.4 MB/s eta 0:00:02
#    --------------------- ------------------ 54.9/101.7 MB 54.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 56.4/101.7 MB 46.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 56.6/101.7 MB 40.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 57.5/101.7 MB 36.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 59.3/101.7 MB 36.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 60.2/101.7 MB 32.8 MB/s eta 0:00:02
#    ------------------------- -------------- 63.8/101.7 MB 34.4 MB/s eta 0:00:02
#    ------------------------- -------------- 65.3/101.7 MB 32.7 MB/s eta 0:00:02
#    -------------------------- ------------- 66.7/101.7 MB 32.7 MB/s eta 0:00:02
#    -------------------------- ------------- 68.3/101.7 MB 36.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 74.3/101.7 MB 65.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 76.2/101.7 MB 65.6 MB/s eta 0:00:01
#    ------------------------------ --------- 77.7/101.7 MB 65.6 MB/s eta 0:00:01
#    ------------------------------- -------- 81.1/101.7 MB 65.6 MB/s eta 0:00:01
#    -------------------------------- ------- 83.3/101.7 MB 54.7 MB/s eta 0:00:01
#    --------------------------------- ------ 86.2/101.7 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 87.9/101.7 MB 54.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 89.8/101.7 MB 54.7 MB/s eta 0:00:01
#    ------------------------------------ --- 93.6/101.7 MB 59.5 MB/s eta 0:00:01
#    ------------------------------------- -- 95.5/101.7 MB 54.7 MB/s eta 0:00:01
#    -------------------------------------- - 97.4/101.7 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  100.1/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  101.7/101.7 MB 59.5 MB/s eta 0:00:01
#    ---------------------------------------- 101.7/101.7 MB 7.9 MB/s eta 0:00:00
# Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Downloading lightgbm-4.5.0-py3-none-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 46.3 MB/s eta 0:00:00
# Downloading optbinning-0.20.0-py3-none-any.whl (213 kB)
#    ---------------------------------------- 0.0/213.9 kB ? eta -:--:--
#    ---------------------------------------- 213.9/213.9 kB ? eta 0:00:00
# Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
#    ---------------------------------------- 0.0/262.6 kB ? eta -:--:--
#    --------------------------------------- 262.6/262.6 kB 15.8 MB/s eta 0:00:00
# Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------- ----------------- 2.7/4.7 MB 86.9 MB/s eta 0:00:01
#    ---------------------------------------  4.7/4.7 MB 76.1 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 50.2 MB/s eta 0:00:00
# Downloading visions-0.7.4-py3-none-any.whl (102 kB)
#    ---------------------------------------- 0.0/102.4 kB ? eta -:--:--
#    ---------------------------------------- 102.4/102.4 kB 5.8 MB/s eta 0:00:00
# Downloading sqldf-0.4.2-py3-none-any.whl (4.3 kB)
# Downloading xgboost-2.1.4-py3-none-win_amd64.whl (124.9 MB)
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#     --------------------------------------- 2.9/124.9 MB 61.4 MB/s eta 0:00:02
#    - -------------------------------------- 5.4/124.9 MB 57.8 MB/s eta 0:00:03
#    -- ------------------------------------- 8.7/124.9 MB 61.5 MB/s eta 0:00:02
#    --- ------------------------------------ 11.6/124.9 MB 59.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 14.3/124.9 MB 59.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 16.8/124.9 MB 65.6 MB/s eta 0:00:02
#    ------ --------------------------------- 19.7/124.9 MB 65.6 MB/s eta 0:00:02
#    ------- -------------------------------- 22.8/124.9 MB 65.6 MB/s eta 0:00:02
#    -------- ------------------------------- 25.7/124.9 MB 59.5 MB/s eta 0:00:02
#    --------- ------------------------------ 28.5/124.9 MB 65.2 MB/s eta 0:00:02
#    --------- ------------------------------ 31.1/124.9 MB 65.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 34.2/124.9 MB 59.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 35.5/124.9 MB 54.7 MB/s eta 0:00:02
#    ------------ --------------------------- 37.5/124.9 MB 50.4 MB/s eta 0:00:02
#    ------------ --------------------------- 39.7/124.9 MB 50.4 MB/s eta 0:00:02
#    ------------- -------------------------- 41.3/124.9 MB 43.5 MB/s eta 0:00:02
#    ------------- -------------------------- 42.5/124.9 MB 40.9 MB/s eta 0:00:03
#    -------------- ------------------------- 46.1/124.9 MB 46.7 MB/s eta 0:00:02
#    --------------- ------------------------ 47.7/124.9 MB 43.7 MB/s eta 0:00:02
#    --------------- ------------------------ 48.5/124.9 MB 40.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 51.3/124.9 MB 43.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 55.5/124.9 MB 54.7 MB/s eta 0:00:02
#    ------------------ --------------------- 58.2/124.9 MB 65.6 MB/s eta 0:00:02
#    ------------------ --------------------- 58.3/124.9 MB 50.4 MB/s eta 0:00:02
#    ------------------- -------------------- 59.5/124.9 MB 46.7 MB/s eta 0:00:02
#    ------------------- -------------------- 59.6/124.9 MB 40.9 MB/s eta 0:00:02
#    ------------------- -------------------- 60.8/124.9 MB 36.4 MB/s eta 0:00:02
#    ------------------- -------------------- 61.6/124.9 MB 32.7 MB/s eta 0:00:02
#    ------------------- -------------------- 61.6/124.9 MB 32.7 MB/s eta 0:00:02
#    -------------------- ------------------- 62.8/124.9 MB 26.2 MB/s eta 0:00:03
#    -------------------- ------------------- 62.8/124.9 MB 26.2 MB/s eta 0:00:03
#    -------------------- ------------------- 63.2/124.9 MB 21.8 MB/s eta 0:00:03
#    -------------------- ------------------- 65.1/124.9 MB 20.5 MB/s eta 0:00:03
#    -------------------- ------------------- 65.1/124.9 MB 20.5 MB/s eta 0:00:03
#    --------------------- ------------------ 66.5/124.9 MB 18.2 MB/s eta 0:00:04
#    --------------------- ------------------ 66.5/124.9 MB 18.2 MB/s eta 0:00:04
#    --------------------- ------------------ 66.8/124.9 MB 15.6 MB/s eta 0:00:04
#    --------------------- ------------------ 66.8/124.9 MB 15.6 MB/s eta 0:00:04
#    --------------------- ------------------ 67.6/124.9 MB 13.6 MB/s eta 0:00:05
#    --------------------- ------------------ 67.6/124.9 MB 13.6 MB/s eta 0:00:05
#    --------------------- ------------------ 67.8/124.9 MB 12.1 MB/s eta 0:00:05
#    --------------------- ------------------ 68.4/124.9 MB 11.7 MB/s eta 0:00:05
#    ---------------------- ----------------- 68.9/124.9 MB 12.6 MB/s eta 0:00:05
#    ---------------------- ----------------- 69.3/124.9 MB 11.9 MB/s eta 0:00:05
#    ---------------------- ----------------- 69.3/124.9 MB 11.1 MB/s eta 0:00:06
#    ---------------------- ----------------- 69.7/124.9 MB 10.7 MB/s eta 0:00:06
#    ---------------------- ----------------- 70.3/124.9 MB 10.9 MB/s eta 0:00:06
#    ---------------------- ----------------- 70.3/124.9 MB 10.9 MB/s eta 0:00:06
#    ---------------------- ----------------- 70.5/124.9 MB 9.9 MB/s eta 0:00:06
#    ---------------------- ----------------- 70.5/124.9 MB 9.9 MB/s eta 0:00:06
#    ---------------------- ----------------- 71.0/124.9 MB 9.1 MB/s eta 0:00:06
#    ---------------------- ----------------- 71.0/124.9 MB 9.1 MB/s eta 0:00:06
#    ---------------------- ----------------- 71.1/124.9 MB 8.7 MB/s eta 0:00:07
#    ---------------------- ----------------- 71.3/124.9 MB 8.5 MB/s eta 0:00:07
#    ---------------------- ----------------- 71.4/124.9 MB 8.2 MB/s eta 0:00:07
#    ----------------------- ---------------- 72.4/124.9 MB 8.4 MB/s eta 0:00:07
#    ----------------------- ---------------- 73.8/124.9 MB 8.8 MB/s eta 0:00:06
#    ----------------------- ---------------- 74.6/124.9 MB 8.7 MB/s eta 0:00:06
#    ------------------------ --------------- 75.4/124.9 MB 9.0 MB/s eta 0:00:06
#    ------------------------ --------------- 76.0/124.9 MB 8.7 MB/s eta 0:00:06
#    ------------------------ --------------- 76.2/124.9 MB 8.3 MB/s eta 0:00:06
#    ------------------------ --------------- 77.7/124.9 MB 9.5 MB/s eta 0:00:05
#    ------------------------ --------------- 78.0/124.9 MB 10.2 MB/s eta 0:00:05
#    ------------------------- -------------- 78.8/124.9 MB 10.2 MB/s eta 0:00:05
#    ------------------------- -------------- 79.5/124.9 MB 10.2 MB/s eta 0:00:05
#    ------------------------- -------------- 80.1/124.9 MB 11.3 MB/s eta 0:00:04
#    ------------------------- -------------- 80.1/124.9 MB 10.7 MB/s eta 0:00:05
#    ------------------------- -------------- 81.1/124.9 MB 12.8 MB/s eta 0:00:04
#    ------------------------- -------------- 81.1/124.9 MB 12.8 MB/s eta 0:00:04
#    -------------------------- ------------- 81.3/124.9 MB 13.4 MB/s eta 0:00:04
#    -------------------------- ------------- 81.8/124.9 MB 13.9 MB/s eta 0:00:04
#    -------------------------- ------------- 82.1/124.9 MB 13.1 MB/s eta 0:00:04
#    -------------------------- ------------- 83.4/124.9 MB 13.1 MB/s eta 0:00:04
#    -------------------------- ------------- 84.3/124.9 MB 13.1 MB/s eta 0:00:04
#    --------------------------- ------------ 84.4/124.9 MB 12.8 MB/s eta 0:00:04
#    --------------------------- ------------ 85.2/124.9 MB 12.8 MB/s eta 0:00:04
#    --------------------------- ------------ 86.0/124.9 MB 13.1 MB/s eta 0:00:03
#    --------------------------- ------------ 86.4/124.9 MB 12.9 MB/s eta 0:00:03
#    ---------------------------- ----------- 87.6/124.9 MB 12.8 MB/s eta 0:00:03
#    ---------------------------- ----------- 89.3/124.9 MB 13.9 MB/s eta 0:00:03
#    ----------------------------- ---------- 91.2/124.9 MB 16.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 91.9/124.9 MB 19.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 91.9/124.9 MB 19.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 92.5/124.9 MB 19.2 MB/s eta 0:00:02
#    ------------------------------ --------- 93.9/124.9 MB 18.7 MB/s eta 0:00:02
#    ------------------------------ --------- 94.5/124.9 MB 19.9 MB/s eta 0:00:02
#    ------------------------------ --------- 94.6/124.9 MB 18.2 MB/s eta 0:00:02
#    ------------------------------ --------- 95.0/124.9 MB 17.7 MB/s eta 0:00:02
#    ------------------------------- -------- 97.2/124.9 MB 21.9 MB/s eta 0:00:02
#    ------------------------------- -------- 97.2/124.9 MB 21.9 MB/s eta 0:00:02
#    ------------------------------- -------- 98.2/124.9 MB 18.7 MB/s eta 0:00:02
#    ------------------------------- ------- 100.4/124.9 MB 19.3 MB/s eta 0:00:02
#    --------------------------------- ----- 105.9/124.9 MB 46.7 MB/s eta 0:00:01
#    ---------------------------------- ---- 109.0/124.9 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------- ---- 111.0/124.9 MB 81.8 MB/s eta 0:00:01
#    ----------------------------------- --- 113.5/124.9 MB 59.5 MB/s eta 0:00:01
#    ------------------------------------ -- 116.0/124.9 MB 54.7 MB/s eta 0:00:01
#    ------------------------------------ -- 118.4/124.9 MB 50.4 MB/s eta 0:00:01
#    ------------------------------------- - 120.7/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  123.6/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 54.7 MB/s eta 0:00:01
#    ---------------------------------------- 124.9/124.9 MB 4.3 MB/s eta 0:00:00
# Downloading joblib-1.1.1-py2.py3-none-any.whl (309 kB)
#    ---------------------------------------- 0.0/309.8 kB ? eta -:--:--
#    --------------------------------------- 309.8/309.8 kB 18.7 MB/s eta 0:00:00
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Downloading multimethod-2.0-py3-none-any.whl (9.8 kB)
# Downloading ortools-9.11.4210-cp311-cp311-win_amd64.whl (142.5 MB)
#    ---------------------------------------- 0.0/142.5 MB ? eta -:--:--
#     --------------------------------------- 2.5/142.5 MB 79.4 MB/s eta 0:00:02
#     --------------------------------------- 3.3/142.5 MB 35.1 MB/s eta 0:00:04
#    -- ------------------------------------- 8.4/142.5 MB 59.6 MB/s eta 0:00:03
#    -- ------------------------------------- 10.2/142.5 MB 59.1 MB/s eta 0:00:03
#    --- ------------------------------------ 13.9/142.5 MB 72.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 15.8/142.5 MB 59.5 MB/s eta 0:00:03
#    ---- ----------------------------------- 17.5/142.5 MB 50.1 MB/s eta 0:00:03
#    ----- ---------------------------------- 19.6/142.5 MB 46.9 MB/s eta 0:00:03
#    ------ --------------------------------- 21.7/142.5 MB 46.9 MB/s eta 0:00:03
#    ------ --------------------------------- 24.2/142.5 MB 46.7 MB/s eta 0:00:03
#    ------- -------------------------------- 25.4/142.5 MB 43.7 MB/s eta 0:00:03
#    ------- -------------------------------- 27.9/142.5 MB 43.7 MB/s eta 0:00:03
#    -------- ------------------------------- 30.2/142.5 MB 54.7 MB/s eta 0:00:03
#    --------- ------------------------------ 32.7/142.5 MB 50.4 MB/s eta 0:00:03
#    --------- ------------------------------ 34.1/142.5 MB 43.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 35.8/142.5 MB 46.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 38.7/142.5 MB 46.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 41.7/142.5 MB 50.1 MB/s eta 0:00:03
#    ------------ --------------------------- 44.2/142.5 MB 54.7 MB/s eta 0:00:02
#    ------------- -------------------------- 47.5/142.5 MB 65.6 MB/s eta 0:00:02
#    ------------- -------------------------- 48.8/142.5 MB 59.5 MB/s eta 0:00:02
#    -------------- ------------------------- 51.2/142.5 MB 59.8 MB/s eta 0:00:02
#    -------------- ------------------------- 53.3/142.5 MB 50.4 MB/s eta 0:00:02
#    --------------- ------------------------ 55.8/142.5 MB 46.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 58.2/142.5 MB 46.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 61.1/142.5 MB 50.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 63.7/142.5 MB 54.7 MB/s eta 0:00:02
#    ------------------ --------------------- 66.3/142.5 MB 54.7 MB/s eta 0:00:02
#    ------------------- -------------------- 69.1/142.5 MB 59.5 MB/s eta 0:00:02
#    ------------------- -------------------- 70.1/142.5 MB 54.7 MB/s eta 0:00:02
#    -------------------- ------------------- 73.8/142.5 MB 54.4 MB/s eta 0:00:02
#    --------------------- ------------------ 76.3/142.5 MB 50.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 78.9/142.5 MB 50.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 80.8/142.5 MB 54.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 82.8/142.5 MB 50.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 84.7/142.5 MB 46.7 MB/s eta 0:00:02
#    ------------------------ --------------- 87.3/142.5 MB 50.1 MB/s eta 0:00:02
#    ------------------------- -------------- 90.8/142.5 MB 54.7 MB/s eta 0:00:01
#    -------------------------- ------------- 93.1/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------- ------------ 96.5/142.5 MB 73.1 MB/s eta 0:00:01
#    --------------------------- ------------ 98.6/142.5 MB 65.6 MB/s eta 0:00:01
#    --------------------------- ----------- 101.5/142.5 MB 59.5 MB/s eta 0:00:01
#    ---------------------------- ---------- 104.2/142.5 MB 59.5 MB/s eta 0:00:01
#    ---------------------------- ---------- 105.6/142.5 MB 50.4 MB/s eta 0:00:01
#    ----------------------------- --------- 107.5/142.5 MB 59.5 MB/s eta 0:00:01
#    ------------------------------ -------- 110.0/142.5 MB 54.4 MB/s eta 0:00:01
#    ------------------------------- ------- 113.2/142.5 MB 50.4 MB/s eta 0:00:01
#    ------------------------------- ------- 116.5/142.5 MB 65.6 MB/s eta 0:00:01
#    ------------------------------- ------- 116.8/142.5 MB 54.7 MB/s eta 0:00:01
#    -------------------------------- ------ 117.2/142.5 MB 46.7 MB/s eta 0:00:01
#    -------------------------------- ------ 119.6/142.5 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------- ---- 125.8/142.5 MB 54.7 MB/s eta 0:00:01
#    ----------------------------------- --- 128.8/142.5 MB 93.0 MB/s eta 0:00:01
#    ----------------------------------- --- 129.2/142.5 MB 73.1 MB/s eta 0:00:01
#    ------------------------------------ -- 131.5/142.5 MB 54.7 MB/s eta 0:00:01
#    ------------------------------------ -- 134.5/142.5 MB 46.7 MB/s eta 0:00:01
#    ------------------------------------- - 137.6/142.5 MB 46.7 MB/s eta 0:00:01
#    ------------------------------------- - 138.7/142.5 MB 43.7 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------------  142.4/142.5 MB 59.5 MB/s eta 0:00:01
#    ---------------------------------------- 142.5/142.5 MB 6.2 MB/s eta 0:00:00
# Downloading phik-0.12.4-cp311-cp311-win_amd64.whl (667 kB)
#    ---------------------------------------- 0.0/667.1 kB ? eta -:--:--
#    --------------------------------------- 667.1/667.1 kB 20.5 MB/s eta 0:00:00
# Downloading ropwr-1.1.0-py3-none-any.whl (17 kB)
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/47.1 kB ? eta -:--:--
#    ---------------------------------------- 47.1/47.1 kB ? eta 0:00:00
# Downloading cvxpy-1.6.0-cp311-cp311-win_amd64.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 34.6 MB/s eta 0:00:00
# Downloading immutabledict-4.2.1-py3-none-any.whl (4.7 kB)
# Downloading protobuf-5.26.1-cp310-abi3-win_amd64.whl (420 kB)
#    ---------------------------------------- 0.0/420.9 kB ? eta -:--:--
#    --------------------------------------- 420.9/420.9 kB 25.7 MB/s eta 0:00:00
# Downloading ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
#    ---------------------------------------- 0.0/296.7 kB ? eta -:--:--
#    --------------------------------------- 296.7/296.7 kB 17.9 MB/s eta 0:00:00
# Downloading clarabel-0.10.0-cp39-abi3-win_amd64.whl (742 kB)
#    ---------------------------------------- 0.0/742.5 kB ? eta -:--:--
#    --------------------------------------- 742.5/742.5 kB 45.8 MB/s eta 0:00:00
# Downloading osqp-0.6.7.post3-cp311-cp311-win_amd64.whl (293 kB)
#    ---------------------------------------- 0.0/293.0 kB ? eta -:--:--
#    --------------------------------------- 293.0/293.0 kB 18.9 MB/s eta 0:00:00
# Downloading scs-3.2.7.post2-cp311-cp311-win_amd64.whl (7.4 MB)
#    ---------------------------------------- 0.0/7.4 MB ? eta -:--:--
#    -------------- ------------------------- 2.7/7.4 MB 58.2 MB/s eta 0:00:01
#    ------------------------- -------------- 4.8/7.4 MB 50.4 MB/s eta 0:00:01
#    ---------------------------------------  7.4/7.4 MB 59.3 MB/s eta 0:00:01
#    ---------------------------------------  7.4/7.4 MB 59.3 MB/s eta 0:00:01
#    ---------------------------------------- 7.4/7.4 MB 33.9 MB/s eta 0:00:00
# Downloading qdldl-0.1.7.post5-cp311-cp311-win_amd64.whl (90 kB)
#    ---------------------------------------- 0.0/90.5 kB ? eta -:--:--
#    ---------------------------------------- 90.5/90.5 kB 5.0 MB/s eta 0:00:00
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27091 sha256=d2f56d1cee47418243442a47bcd690f36c089bb7a98b73784d52d796b97b1cf0
#   Stored in directory: c:\users\12098\appdata\local\pip\cache\wheels\8d\55\1a\19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# Installing collected packages: sqldf, htmlmin, tangled-up-in-unicode, protobuf, multimethod, joblib, immutabledict, graphviz, xgboost, scs, qdldl, lightgbm, imagehash, clarabel, visions, phik, osqp, ortools, catboost, missingno, imblearn, cvxpy, ropwr, pandas-profiling, optbinning
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.2.0
#     Uninstalling joblib-1.2.0:
#       Successfully uninstalled joblib-1.2.0
# Successfully installed catboost-1.2.7 clarabel-0.10.0 cvxpy-1.6.0 graphviz-0.20.3 htmlmin-0.1.12 imagehash-4.3.2 imblearn-0.0 immutabledict-4.2.1 joblib-1.1.1 lightgbm-4.5.0 missingno-0.5.2 multimethod-2.0 optbinning-0.20.0 ortools-9.11.4210 osqp-0.6.7.post3 pandas-profiling-3.2.0 phik-0.12.4 protobuf-5.26.1 qdldl-0.1.7.post5 ropwr-1.1.0 scs-3.2.7.post2 sqldf-0.4.2 tangled-up-in-unicode-0.2.0 visions-0.7.4 xgboost-2.1.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.30.0 requires protobuf<5,>=3.20, but you have protobuf 5.26.1 which is incompatible.
# tensorflow-intel 2.16.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.26.1 which is incompatible.

# %%
pip install pandasql
# Out:
# Collecting pandasql
#   Downloading pandasql-0.7.3.tar.gz (26 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\12098\anaconda3.1\lib\site-packages (from pandasql) (1.26.4)
# Requirement already satisfied: pandas in c:\users\12098\anaconda3.1\lib\site-packages (from pandasql) (2.1.4)
# Requirement already satisfied: sqlalchemy in c:\users\12098\anaconda3.1\lib\site-packages (from pandasql) (2.0.25)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\12098\anaconda3.1\lib\site-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\12098\anaconda3.1\lib\site-packages (from pandas->pandasql) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\12098\anaconda3.1\lib\site-packages (from pandas->pandasql) (2023.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\12098\anaconda3.1\lib\site-packages (from sqlalchemy->pandasql) (4.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\12098\anaconda3.1\lib\site-packages (from sqlalchemy->pandasql) (3.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\12098\anaconda3.1\lib\site-packages (from python-dateutil>=2.8.2->pandas->pandasql) (1.16.0)
# Building wheels for collected packages: pandasql
#   Building wheel for pandasql (setup.py): started
#   Building wheel for pandasql (setup.py): finished with status 'done'
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26798 sha256=bfad48d3bf1144d404b5705d31a4f536f47af13565bd58ebb8e57b06f3ab806a
#   Stored in directory: c:\users\12098\appdata\local\pip\cache\wheels\68\5d\a5\edc271b998f909801d7956959f699b976cc9896075dc47c153
# Successfully built pandasql
# Installing collected packages: pandasql
# Successfully installed pandasql-0.7.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Import the Libraries

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"
import os
import datetime
import pandasql as psql
import dateutil.relativedelta
from glob import iglob # Global directory
from datetime import date
from itertools import product
from IPython.display import display, HTML # Display image on jupyter notebook
from datetime import datetime
from typing import List, Tuple, Iterable
from tqdm import tqdm # Show data processing bar
import re
from datetime import datetime as dt
from dateutil.relativedelta import relativedelta
 
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 70)

# %% [markdown]
# #### Data Preprocessing Function Details
#
# 1- Read_files_in_data_directory (A function that reads all .csv and .xlsx files in Data directory and returns a dictionary of DataFrames)
#
# 2- Check dataframes (Ensure all dataframes in dictionary)
#
# 3- add_year_month_and_filter_oneoff (McK_Oneoff take required columns and change column name DateTime(Year_Month_Obs)
#
# 4- transform_credit_report_to_time_series (The BSI_Creditreporting dataset, Which contains three years of horizontal data for each borrower, Needs to be converted to three years of vertical data of each borrower.)
#
# 5- rename_and_transform_logins_columns (Rename the column name & typecasting datatypes in MLW_Login Data, Extract Year_Month data)
#
# 6- count_monthly_logins (Use Year_Month Column Data, A function provide a output monthly login count each borrower)
#
# 7- add_fips_to_training_oneoff (Mapping the PropertyZipCode(McK_Oneoff) & ZIP(Add_Fips_Mapping))
#
# 8- clean_domographic (Remove the unnecessary columns)

# %%
# a function that reads all .csv and .xlsx files in Data directory and returns a dictionary of DataFrames 
# with filenames as keys and loaded datafrmaes as values

def read_files_in_data_directory(directory_path, is_BSI_data=True):
    # Ensure the directory path is valid
    if not os.path.isdir(directory_path):
        raise ValueError("Invalid directory path")

    # Initialize an empty dictionary to store DataFrames
    dataframes = {}
    specific_month = ''
    
    # Loop through files in the directory
    for filename in tqdm(os.listdir(directory_path), desc ="Loading Data Progress"):
        file_path = os.path.join(directory_path, filename)

        # Check if the file is a CSV or Excel file
        if filename.lower().endswith(('.csv', '.xlsx')):
            # Read the file into a DataFrame
            if filename.lower().endswith('.csv'):
                df = pd.read_csv(file_path, low_memory=False) # , error_bad_lines = False
            elif filename.lower().endswith('.xlsx'):
                df = pd.read_excel(file_path)
            
            # if 'oneoff' in filename.lower():
            if any(key_word in filename.lower() for key_word in ['one', 'off']):
                raw_data_info = filename[:-4]
                dataframe_name = 'McK_Oneoff'
                pattern = '|'.join(map(re.escape, ['_', '.', '-']))
                # Use re.split to split the string based on the delimiters
                result = re.split(pattern, filename)
                specific_month = '_'.join(result[-3:-1]).upper() + '_'
            elif 'credit' in filename.lower():
                dataframe_name = 'BSI_CREDITREPORTING'
            elif 'mlw' in filename.lower():
                dataframe_name = 'Logins'
            
            elif 'interest' in filename.lower():
                dataframe_name = 'Avg_interest_rate'
            elif 'demographic' in filename.lower():
                dataframe_name = 'Demographic'
            elif 'zip' in filename.lower():
                dataframe_name = 'Zip_fips_lookup'
            elif 'hpi' or 'house' in filename.lower():
                dataframe_name = 'Purchase_index'
            else:
                dataframe_name = os.path.splitext(filename)[0]

            print(f"{dataframe_name} is loaded: {df.shape}")
            print()
            # Add the DataFrame to the dictionary with the filename as the key
            dataframes[dataframe_name] = df
            
    if is_bsi_data:
        bsi_or_public = 'BSI'
    else:
        bsi_or_public = 'Public'
    print(f">>>>>> Loading {bsi_or_public} Data Completed <<<<<<<")
    return dataframes, specific_month, raw_data_info if is_bsi_data else dataframes

# %%
def check_dataframes(BSI_dataframes, public_dataframes, needed_dataframes = ['McK_Oneoff',
                                                                            'BSI_CREDITREPORTING',
                                                                            'Logins',
                                                                            'Avg_interest_rate',
                                                                            'Zip_fips_lookup',
                                                                            'Purchase_index',
                                                                            'Demographic']):
    
    combined_dataframe_dictionaries = {**BSI_dataframes,**public_dataframes}
    #  Check if all the needed dataframes exist
    try:
        for df_name in needed_dataframes:
            if df_name not in combined_dataframe_dictionaries.keys():
                raise NameError(f"{df_name} data not found!")
        print(">>>>>> All needed dataframes found <<<<<<")
    except NameError as e:
        print(f"Error: {e}")
        raise  # Raise the exception to halt the program

# %%
def add_year_month_and_filter_oneoff(McK_Oneoff, cols=None):
    """
    

    Parameters:
    - McK_Oneoff (pd.DataFrame): The input DataFrame containing loan data.
    - cols (list, optional): A list of column names to be selected in the final DataFrame.
                             If not provided, default columns will be selected.

    Returns:
    - pd.DataFrame: A DataFrame containing the latest occurrence of each loan with selected columns.

    Steps:
    1. Converts the 'DataDate' column to datetime format.
    2. Identifies the index of the last occurrence for each 'LoanNumber' based on 'DataDate'.
    3. Filters the DataFrame to include only the rows with the identified indices.
    4. Adds a new column 'Year_Month_Obs' formatted as '%Y-%m'.
    5. Resets the DataFrame index.
    6. Selects and retains specific columns from the DataFrame.

    Note:
    The function modifies the input DataFrame in-place and prints a message indicating the operation.
    """

    McK_Oneoff['DataDate']=pd.to_datetime(McK_Oneoff['DataDate'],format='mixed')
    # last_occurrence_index = McK_Oneoff.groupby('LoanNumber')['DataDate'].idxmax()
    # McK_Oneoff = McK_Oneoff[McK_Oneoff.index.isin(last_occurrence_index)].reset_index(drop=True)
    # clean and format
    McK_Oneoff['Year_Month_Obs']=McK_Oneoff['DataDate'].dt.strftime('%Y-%m')
    McK_Oneoff=McK_Oneoff.reset_index(drop=True)

    print(">>>>> Year_Month_Obs column added to McK_Oneoff  <<<<<")

    # select columns
    if not cols:
        cols=[
            'LoanNumber',
            'LoanType',
            'PrincipalBalance',
            'NextDueDate',
            'InterestPaidToDate',
            'DateLastPayment',
            'InterestRate',
            'OriginalInterestRate',
            'PropertyCityName',
            'PropertyState',
            'PropertyZipCode',
            'MailingCity',
            'MailingState',
            'MailingZip',
            'FICO_Score',
            'FicoDate',
            'BankruptcyFlag',
            'LossMitigationStatus',
            'ForeclosureStatus',
            'DLQ_Status',
            'NoteDate',
            'ServicingDate',
            'TransferDate',
            'PiPmt',
            'EscrowPayment',
            'EscrowBalance',
            'ReportToCreditBureau',
            'AppraisalDate',
            'AppraisedAmount',
            'Original_Ltv_Calc',
            'CurrentLTV',
            'PriorServicerName',
            'InvestorOwner',
            'AcquiredPortfolioName',
            'PrimaryBorrowerOptOut',
            'SecondaryBorrowerOptOut',
            'TermOfLoan',
            'RemainingTerm',
            'FIXED ARM',
            'SaleAmount',
            'OriginalBalance',
            'RawLeadType',
            'ForbearanceFlag',
            'Year_Month_Obs'
        ]

    McK_Oneoff = McK_Oneoff[cols]
    print(">>>>> McK_Oneoff filtered for the needed columns <<<<<")

    return  McK_Oneoff

# %%
def transform_credit_report_to_time_series(BSI_CreditReporting, Year_Month_Obs=None):
    print("After implementing CB_RPTD_STA, CB_RPTG_STA and CLOSE_CD_DB000 check")
    filtered_df = BSI_CreditReporting.copy()
    print(filtered_df.shape)
    if not Year_Month_Obs:
        Year_Month_Obs=[
            '2023-01',
            '2023-02',
            '2023-03',
            '2023-04',
            '2023-05',
            '2023-06',
            '2023-07',
            '2023-08',
            '2023-09',
            '2023-10',
            '2023-11',
            '2023-12',
            '2022-01',
            '2022-02',
            '2022-03',
            '2022-04',
            '2022-05',
            '2022-06',
            '2022-07',
            '2022-08',
            '2022-09',
            '2022-10',
            '2022-11',
            '2022-12',
            '2021-01',
            '2021-02',
            '2021-03',
            '2021-04',
            '2021-05',
            '2021-06',
            '2021-07',
            '2021-08',
            '2021-09',
            '2021-10',
            '2021-11',
            '2021-12',
        ]
 
    All_LoanNumber=[]
    All_Year_Month_Obs=[]
    All_History=[]
    for loan in filtered_df['ACCT_NBR']:
        History=filtered_df[filtered_df['ACCT_NBR']==loan].iloc[:,-37:-1]
        LoanNumber=[loan]*36
        x1=LoanNumber
        x2=Year_Month_Obs
        x3=History.iloc[0,:].to_list()
        All_LoanNumber.extend(x1)
        All_Year_Month_Obs.extend(x2)
        All_History.extend(x3)
 
    data = {'LoanNumber': All_LoanNumber,
            'Year_Month_Obs': All_Year_Month_Obs,
            'CREDIT_BUREAU_PAYMENT_HISTORY':All_History}
    BSI_CreditReporting = pd.DataFrame()
    BSI_CreditReporting = pd.DataFrame(data)
    print('>>>>> Credit Report Transformed to Timeseries <<<<<<')
    return BSI_CreditReporting
 
#Function to automate 2 month lag data
#We are picking the current year month current from Training file and filter data to credit reporting file
# from datetime import datetime as dt
# from dateutil.relativedelta import relativedelta
 
# def pick_1yr_data(source_df):
#     actual_date = source_df.Year_Month_Obs.unique()[0]
#     actual_date_formatted = dt.strptime(actual_date,'%Y-%m')
#     start_date = actual_date_formatted + relativedelta(months = -13)
#     end_date = actual_date_formatted + relativedelta(months = -2)
#     return start_date, end_date
 
# #If CBPH data belongs to category ('B','D','.',0), assign 0 else 1
# def Credit_feature_enhancement(CBPH, YMO,start_date, end_date):
#     ymo = dt.strptime(YMO,'%Y-%m')
#     if ymo >= start_date and ymo <= end_date: 
#         if CBPH in ('B','D','.',0):
#             return 0
#         else:
#             return 1
#     else:
#         return 0

# %%
def rename_and_transform_logins_columns(logins):
    """
    Rename and transform columns in a DataFrame representing login data.

    Args:
        logins (pd.DataFrame): A DataFrame containing login data with columns 'LoanNumber' and 'Date'.

    Returns:
        pd.DataFrame: A DataFrame with columns renamed and additional columns added:
            - 'LoanNumberPlain': Renamed from 'LoanNumber'.
            - 'LoginDate': Converted to a datetime format from the original 'Date'.
            - 'Login_Year_Month': New column derived from 'LoginDate' with the format 'YYYY-MM'.

    Note:
        This function modifies the input DataFrame in place.
    """
    logins.rename(columns={'LoanNumber': 'LoanNumberPlain',
                           'Date': 'LoginDate'}, inplace=True)
    
    logins['LoginDate']=pd.to_datetime(logins['LoginDate'],format = 'mixed')
    logins['Login_Year_Month']=logins['LoginDate'].dt.strftime('%Y-%m')
    logins['LoanNumberPlain']=logins['LoanNumberPlain'].astype(int)
    print('>>>>> Logins columns renamed and transformed <<<<<<')
    return logins

# %%
def count_monthly_logins(Logins):
    """
    Count the number of logins per month for each LoanNumberPlain.

    This function uses the variable 'Logins' to generate a DataFrame
    containing the counts of logins for each LoanNumberPlain in each Login_Year_Month.

    Returns:
    DataFrame: A DataFrame containing the columns 'LoanNumberPlain',
               'Login_Year_Month', and 'Login_Count' representing the monthly
               login counts.

    Note:
    - The 'Logins' variable is assumed to be available for SQL queries.
    - The generated DataFrame includes counts of logins grouped by
      LoanNumberPlain and Login_Year_Month.
    - The function also prints a message indicating that the monthly login count
      has been generated.
    """
    Monthly_Login_Count=sqldf.run('''
                                SELECT LoanNumberPlain, Login_Year_Month, count(Login_Year_Month) as Login_Count
                                FROM Logins
                                GROUP BY LoanNumberPlain,  Login_Year_Month
                                '''
                                )
    print('>>>>> Monthly Login Count Generated <<<<<<')
    return Monthly_Login_Count

# %%
def add_fips_to_training_oneoff(training_oneoff, Zip_fips_lookup): # Take two argument Mck_Oneoff & add_fips
    training_oneoff['FIPS'] = np.nan # Mck_Oneoff dataset create a column name FIPS fills NaN.
    for i in range(training_oneoff.shape[0]): # Iterate the mck_oneoff data from row 0 to till end. use of shape[0].
    # for i in range(30):
        zip = int(training_oneoff.loc[i,'PropertyZipCode'][-5:]) # Taking the last character propertyzip column of the current row in mck_oneoff, convert int
        row = Zip_fips_lookup.index[Zip_fips_lookup['ZIP'] == zip] # Find the index(row number) in the Zips_fips dataframe where the ZIP column matches the extracted zip code.
        if len(row)==0: # Check the zip code ==0 then pass the else condition, if true then store the fips code in fips column
            pass
        else:
            row = row[0]
            fips = Zip_fips_lookup.loc[row,'STCOUNTYFP'] 
            training_oneoff.loc[i,'FIPS'] = fips
    print('>>>>> FIPS Added to McK_Oneoff <<<<<<')
    return training_oneoff

# %%
def clean_domographic(Demographic, keep_only_needed_column=False):
    Demographic = Demographic.loc[:, ~Demographic.columns.str.contains('^Unnamed')]
    columns=[
    'code',
    'geography',
    'Percent_EDUCATIONAL_ATTAINMENT_Population_25_years_and_over_Bachelors_degree_or_higher',
    'Percent_VEHICLES_AVAILABLE_Occupied_housing_units_No_vehicles_available',
    'Percent_VEHICLES_AVAILABLE_Occupied_housing_units_1_vehicle_available',
    'Percent_VEHICLES_AVAILABLE_Occupied_housing_units_3_or_more_vehicles_available',
    'Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Agriculture_forestry_fishing_and_hunting_and_mining',
    'Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Construction',
    'Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Manufacturing',
    'Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Wholesale_trade',
    'Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Retail_trade',
    'Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Transportation_and_warehousing_and_utilities',
    'Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Information',
    'Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Finance_and_insurance_and_real_estate_and_rental_and_leasing',
    'Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Professional_scientific_and_management_and_administrative_and_waste_management_services',
    'Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Educational_services_and_health_care_and_social_assistance',
    'Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Arts_entertainment_and_recreation_and_accommodation_and_food_services',
    'Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Other_services_except_public_administration',
    'Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Public_administration',
    'Percent_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_earnings',
    'Percent_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_Social_Security',
    'Percent_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_retirement_income',
    'Percent_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_Supplemental_Security_Income',
    'Percent_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_cash_public_assistance_income',
    'Percent_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_Food_Stamp_over_SNAP_benefits_in_the_past_12_months',
    'Percent_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Nonfamily_households',
    'Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_Median_household_income_dollars',
    'Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_Mean_household_income_dollars',
    'Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_earnings_Mean_earnings_dollars',
    'Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_Social_Security_Mean_Social_Security_income_dollars',
    'Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_retirement_income_Mean_retirement_income_dollars',
    'Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_Supplemental_Security_Income_Mean_Supplemental_Security_Income_dollars',
    'Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_cash_public_assistance_income_Mean_cash_public_assistance_income_dollars',
    'Percent_HEALTH_INSURANCE_COVERAGE_Civilian_noninstitutionalized_population_With_health_insurance_coverage_With_private_health_insurance',
    'Percent_HEALTH_INSURANCE_COVERAGE_Civilian_noninstitutionalized_population_With_health_insurance_coverage_With_public_coverage',
    'Percent_HEALTH_INSURANCE_COVERAGE_Civilian_noninstitutionalized_population_No_health_insurance_coverage',
    'Estimate_EMPLOYMENT_STATUS_Population_16_years_and_over',
    'Percent_EMPLOYMENT_STATUS_Population_16_years_and_over_In_labor_force',
    'Percent_EMPLOYMENT_STATUS_Civilian_labor_force_Unemployment_Rate',
    'Percent_SELECTED_MONTHLY_OWNER_COSTS_AS_A_PERCENTAGE_OF_HOUSEHOLD_INCOME_SMOCAPI_Housing_units_with_a_mortgage_excluding_units_where_SMOCAPI_cannot_be_computed_35_0_percent_or_more',
    'Percent_SELECTED_MONTHLY_OWNER_COSTS_AS_A_PERCENTAGE_OF_HOUSEHOLD_INCOME_SMOCAPI_Housing_unit_without_a_mortgage_excluding_units_where_SMOCAPI_cannot_be_computed_35_0_percent_or_more',
    'Percent_GROSS_RENT_AS_A_PERCENTAGE_OF_HOUSEHOLD_INCOME_GRAPI_Occupied_units_paying_rent_excluding_units_where_GRAPI_cannot_be_computed_35_0_percent_or_more',
    'Percent_HOUSING_TENURE_Occupied_housing_units_Owner_occupied',
    'Percent_HOUSING_TENURE_Occupied_housing_units_Renter_occupied',
    'Percent_HOUSING_OCCUPANCY_Total_housing_units_Vacant_housing_units',
    'GINI_index',
    'Estimate_Median_gross_rent_as_a_percentage_of_household_income',
    'Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_Median_household_income_dollars_1',
    'Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_Mean_household_income_dollars_1',
    'Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_earnings_Mean_earnings_dollars_1',
    'Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_Social_Security_Mean_Social_Security_income_dollars_1',
    'Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_retirement_income_Mean_retirement_income_dollars_1',
    'Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_Supplemental_Security_Income_Mean_Supplemental_Security_Income_dollars_1',
    'Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_cash_public_assistance_income_Mean_cash_public_assistance_income_dollars_1',
    'Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Families_Median_family_income_dollars',
    'Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Families_Mean_family_income_dollars',
    'Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Per_capita_income_dollars',
    'Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Nonfamily_households_Median_nonfamily_income_dollars',
    'Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Nonfamily_households_Mean_nonfamily_income_dollars',
    'Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Median_earnings_for_workers_dollars'
    ]
    Demographic.columns=columns

    
    return Demographic

# %%
# def save_data(data, path, file_name, save_sample=False, display_data=False):
#     data.to_csv(path + file_name + '.csv', index=False)
    
#     if save_sample:
#         data_head=data.sample(frac=0.01)
#         save_data(data_head, path, file_name+'_head', save_sample=False, display_data=False)
#     if display_data:
#         display(data.head())
#     print(f'>>>>> {file_name} Saved <<<<<<')

# %%
# def create_folders(new_folder_path, new_folder_name):
#     try:
#         # Create the directory
#         os.makedirs(new_folder_path)
#         print(f"Directory '{new_folder_name}' _created.")
#     except FileExistsError:
#         print(f"Directory '{new_folder_name}' already exists.")


#     # Create subfolders inside the Output folder
#     subfolders = ['Binning_ready_data', 'WOE_data', 'Loan_numbers', 'Predictions']
#     for subfolder in subfolders:
#         subfolder_path = os.path.join(new_folder_path, subfolder)
#         os.makedirs(subfolder_path)
#         print(f"Subfolder '{new_folder_name}/{subfolder}' created.")

# %%
# Update the root directory & reading the dataframes

root_directory = 'Incedo Transition Folder/1-Data Source/Training Data'
input_path = os.path.join(root_directory,'Input_Data')
BSI_data_path = os.path.join(input_path, 'BSI_data/')
public_data_path = os.path.join(input_path, 'Public_data/')


BSI_dataframes, specific_month, raw_data_info = read_files_in_data_directory(BSI_data_path) # read all BSI dataframes
 
globals().update(BSI_dataframes) # this line creates variables from dataframes keys with the same name
print('Month of Observation:', specific_month)
BSI_dataframe_names = list(BSI_dataframes.keys())
# del BSI_dataframes
print('Extracted specific month:', specific_month)
 
public_dataframes, _, _ = read_files_in_data_directory(public_data_path, False) # read all public dataframes
print(public_dataframes.keys())
globals().update(public_dataframes) # this line creates variables from dataframes keys with the same name
public_dataframe_names = list(public_dataframes.keys())
 
check_dataframes(BSI_dataframes, public_dataframes)
 
McK_Oneoff_1yr = add_year_month_and_filter_oneoff(BSI_dataframes['McK_Oneoff'])
 
print(McK_Oneoff_1yr.shape)
display(McK_Oneoff_1yr.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 9
#       5 BSI_data_path = os.path.join(input_path, 'BSI_data/')
#       6 public_data_path = os.path.join(input_path, 'Public_data/')
# ----> 9 BSI_dataframes, specific_month, raw_data_info = read_files_in_data_directory(BSI_data_path) # read all BSI dataframes
#      11 globals().update(BSI_dataframes) # this line creates variables from dataframes keys with the same name
#      12 print('Month of Observation:', specific_month)
#
# Cell In[3], line 7, in read_files_in_data_directory(directory_path, is_bsi_data)
#       4 def read_files_in_data_directory(directory_path, is_bsi_data=True):
#       5     # Ensure the directory path is valid
#       6     if not os.path.isdir(directory_path):
# ----> 7         raise ValueError("Invalid directory path")
#       9     # Initialize an empty dictionary to store DataFrames
#      10     dataframes = {}
#
# ValueError: Invalid directory path

# %%
# Model Training 1 yr data from Sep-22 to Aug-23

McK_Oneoff_1yr['Year_Month_Obs'] = pd.to_datetime(McK_Oneoff_1yr['Year_Month_Obs'])
print(McK_Oneoff_1yr.shape)
 
import functools
def disjunction_and(*conditions):
    return functools.reduce(np.logical_and, conditions)
 
c_1 = McK_Oneoff_1yr['Year_Month_Obs']>'2022-08' # Sep-2022 to Start
c_2 =McK_Oneoff_1yr['Year_Month_Obs']<='2023-08' # Aug-2023 to End
 
McK_Oneoff = McK_Oneoff_1yr[disjunction_and(c_1,c_2)].reset_index(drop=True)
print(McK_Oneoff.shape)
print(McK_Oneoff['Year_Month_Obs'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 # Model Training 1 yr data from Sep-22 to Aug-23
# ----> 3 McK_Oneoff_1yr['Year_Month_Obs'] = pd.to_datetime(McK_Oneoff_1yr['Year_Month_Obs'])
#       4 print(McK_Oneoff_1yr.shape)
#       6 import functools
#
# NameError: name 'McK_Oneoff_1yr' is not defined

# %% [markdown]
# #### Implementing & Transformation Credit Bureau Payment History Data

# %%
# Sort the dataframe mck_oneoff based on the values in the column "Year_month_obs" in ascending order.
# The groups the sorted dataframe by the column "LoanNumber" and select the the last row for each group. it effectly keeps only the most recent entry for each loan number.
# Reset index dataframe after grouping operation

McK_Oneoff = McK_Oneoff.sort_values(['Year_Month_Obs']).groupby(['LoanNumber']).last().reset_index()
print(McK_Oneoff.shape)
McK_Oneoff.head(2)
# Out:
# (164246, 44)
#    LoanNumber      LoanType  PrincipalBalance NextDueDate InterestPaidToDate  \
# 0         791  CONVENTIONAL          69477.71  2023-10-01         2023-09-01
# 1        1235  CONVENTIONAL          53245.69  2023-08-01         2023-07-01
#
#   DateLastPayment  InterestRate  OriginalInterestRate PropertyCityName  \
# 0      2023-08-01         2.750                 2.750   NORTH WILDWOOD
# 1      2023-07-28         2.875                 2.875            ASTON
#
#   PropertyState PropertyZipCode   MailingCity MailingState MailingZip  \
# 0            NJ           08260  SICKLERVILLE           NJ      08081
# 1            PA           19014         ASTON           PA      19014
#
#    FICO_Score    FicoDate BankruptcyFlag LossMitigationStatus  \
# 0       777.0  2023-01-31           None
# 1       608.0  2023-01-31           None
#
#   ForeclosureStatus DLQ_Status    NoteDate ServicingDate TransferDate  \
# 0              None    CURRENT  2013-03-29    2013-04-19   2013-04-24
# 1              None       1-29  2013-03-15    2013-04-05   2013-04-09
#
#      PiPmt  EscrowPayment  EscrowBalance ReportToCreditBureau AppraisalDate  \
# 0  1425.11           0.00           0.00                    Y    2013-02-01
# 1  1002.92         696.66          19.31                    Y    2013-02-01
#
#    AppraisedAmount  Original_Ltv_Calc  CurrentLTV      PriorServicerName  \
# 0         315000.0              66.67       22.06  ALLIED MORTGAGE GROUP
# 1         232000.0              63.15       22.95  ALLIED MORTGAGE GROUP
#
#      InvestorOwner AcquiredPortfolioName PrimaryBorrowerOptOut  \
# 0    Balbec Fund V     ALLIED [2 - FNMA]                     0
# 1  Balbec Fund III     ALLIED [1 - FNMA]                     0
#
#   SecondaryBorrowerOptOut  TermOfLoan  RemainingTerm FIXED ARM  SaleAmount  \
# 0                       0         180             55     FIXED         0.0
# 1                       0         180             57     FIXED         0.0
#
#    OriginalBalance RawLeadType ForbearanceFlag Year_Month_Obs
# 0         210000.0      Allied            None     2023-08-01
# 1         146500.0      Allied            None     2023-08-01

# %% [markdown]
# Taking 1 year data from Credit Bureau Payment based on Year month obs
#
# Handling credit bureau history feature This is on the basis of last reported date column

# %%
# Filter the data from ['CBR_LAST_REPORT_DATE']>'2022-01']
# Take the data based on CBR_LAST_REPORT_DATE and Lag 2 month

yes_reportclosedate = BSI_CREDITREPORTING[BSI_CREDITREPORTING['CBR_LAST_REPORT_DATE']>'2022-01'].reset_index()
yes_reportclosedate['start_date'] = yes_reportclosedate.CBR_LAST_REPORT_DATE.apply(lambda x: dt.strptime(dt.strftime(x + relativedelta(months = -13),'%Y-%m'), '%Y-%m'))
yes_reportclosedate['end_date'] = yes_reportclosedate.CBR_LAST_REPORT_DATE.apply(lambda x: dt.strptime(dt.strftime(x + relativedelta(months = -2),'%Y-%m'), '%Y-%m'))
yes_reportclosedate.head()
# Out:
#    index  CLOSE_CD_DB000  ACCT_NBR                   PRIM_BWRS_NM_DB001  \
# 0      6               1       791  THADDEUS LUKASZEWICZ
# 1      7               1      1235  HEATHER DIIORIO
# 2      8               1      1262  LEONARD LEIB
# 3     10               1      1571  BETH A SCHULTHEIS
# 4     11               1      1596  WILLIAM J HODGE
#
#   CB_RPTG_STA CBR_LAST_REPORT_DATE CBR_RPTD_OPEND_DATE CBR_RPTD_CLOSE_DATE  \
# 0           Y           2023-10-10          2013-03-29                 NaT
# 1           Y           2023-10-10          2013-03-15                 NaT
# 2           Y           2023-10-10          2013-05-15                 NaT
# 3           Y           2023-10-10          2013-05-03                 NaT
# 4           Y           2023-10-10          2013-04-22                 NaT
#
#   CBR_RPTD_LAST_PAYMENT_DATE CB_RPTD_STA CBR_COMMENT_CD CB_RPT_CMNTS  \
# 0                 2023-09-01          11
# 1                 2023-09-22          11
# 2                 2023-09-01          11
# 3                 2023-09-04          11
# 4                 2023-08-01          11
#
#   CB_RPT_PMT_RT  CBR_RPTD_HIGH_AMOUNT  CBR_RPTD_PAYMENT_AMOUNT  \
# 0                              210000                     1425
# 1                              146500                     1699
# 2                              412500                     3246
# 3                              100500                     1042
# 4                              109100                     1605
#
#    CBR_RPTD_ACTUAL_PAYMENT_AMOUNT  CBR_RPTD_CURRENT_BALANCE  \
# 0                            1425                     68211
# 1                            3399                     53247
# 2                            3346                    136136
# 3                            1042                     37068
# 4                               0                     37174
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_THIS_YEAR_JANUARY  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_THIS_YEAR_FEBRUARY  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_THIS_YEAR_MARCH  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_THIS_YEAR_APRIL  \
# 0                                             0
# 1                                             1
# 2                                             0
# 3                                             0
# 4                                             0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_THIS_YEAR_MAY  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_THIS_YEAR_JUNE  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_THIS_YEAR_JULY  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_THIS_YEAR_AUGUST  \
# 0                                              0
# 1                                              1
# 2                                              0
# 3                                              0
# 4                                              0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_THIS_YEAR_SEP  \
# 0                                           .
# 1                                           .
# 2                                           .
# 3                                           .
# 4                                           .
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_THIS_YEAR_OCTOBER  \
# 0                                               .
# 1                                               .
# 2                                               .
# 3                                               .
# 4                                               .
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_THIS_YEAR_NOVEMBER  \
# 0                                                .
# 1                                                .
# 2                                                .
# 3                                                .
# 4                                                .
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_THIS_YEAR_DECEMBER  \
# 0                                                .
# 1                                                .
# 2                                                .
# 3                                                .
# 4                                                .
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_LAST_YEAR_JANUARY  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_LAST_YEAR_FEBRUARY  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_LAST_YEAR_MARCH  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_LAST_YEAR_APRIL  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_LAST_YEAR_MAY  \
# 0                                           0
# 1                                           1
# 2                                           0
# 3                                           0
# 4                                           0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_LAST_YEAR_JUNE  \
# 0                                            0
# 1                                            1
# 2                                            0
# 3                                            0
# 4                                            0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_LAST_YEAR_JULY  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_LAST_YEAR_AUGUST  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_LAST_YEAR_SEP  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_LAST_YEAR_OCTOBER  \
# 0                                               0
# 1                                               1
# 2                                               0
# 3                                               0
# 4                                               0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_LAST_YEAR_NOVEMBER  \
# 0                                                0
# 1                                                1
# 2                                                0
# 3                                                0
# 4                                                0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_LAST_YEAR_DECEMBER  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_2_YEARS_AGO_JAN  \
# 0                                             .
# 1                                             .
# 2                                             .
# 3                                             .
# 4                                             .
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_2_YEARS_AGO_FEB  \
# 0                                             .
# 1                                             .
# 2                                             .
# 3                                             .
# 4                                             .
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_2_YEARS_AGO_MARCH  \
# 0                                               .
# 1                                               .
# 2                                               .
# 3                                               .
# 4                                               .
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_2_YEARS_AGO_APRIL  \
# 0                                               .
# 1                                               .
# 2                                               .
# 3                                               .
# 4                                               .
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_2_YEARS_AGO_MAY  \
# 0                                             .
# 1                                             .
# 2                                             .
# 3                                             .
# 4                                             .
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_2_YEARS_AGO_JUNE  \
# 0                                              .
# 1                                              .
# 2                                              .
# 3                                              .
# 4                                              .
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_2_YEARS_AGO_JULY  \
# 0                                              .
# 1                                              .
# 2                                              .
# 3                                              .
# 4                                              .
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_2_YEARS_AGO_AUGUST  \
# 0                                                .
# 1                                                .
# 2                                                .
# 3                                                .
# 4                                                .
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_2_YEARS_AGO_SEP  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_2_YEARS_AGO_OCT  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_2_YEARS_AGO_NOV  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#   CREDIT_BUREAU_PAYMENT_HISTORY_2_YEARS_AGO_DEC   DataDate start_date  \
# 0                                             0 2023-10-31 2022-09-01
# 1                                             0 2023-10-31 2022-09-01
# 2                                             0 2023-10-31 2022-09-01
# 3                                             0 2023-10-31 2022-09-01
# 4                                             0 2023-10-31 2022-09-01
#
#     end_date
# 0 2023-08-01
# 1 2023-08-01
# 2 2023-08-01
# 3 2023-08-01
# 4 2023-08-01

# %%
# Transform vertically all loan number with Year_Month_Obs with merging

BSI_CreditReporting_yesclosedate = transform_credit_report_to_time_series(yes_reportclosedate)
BSI_CreditReporting_yesclosedate_1 = BSI_CreditReporting_yesclosedate.merge(yes_reportclosedate[['ACCT_NBR','start_date','end_date']],how='left',left_on='LoanNumber',right_on='ACCT_NBR')
BSI_CreditReporting_yesclosedate_1.head(2)
# Out:
# After implementing CB_RPTD_STA, CB_RPTG_STA and CLOSE_CD_DB000 check
# (174776, 56)
# >>>>> Credit Report Transformed to Timeseries <<<<<<
#    LoanNumber Year_Month_Obs CREDIT_BUREAU_PAYMENT_HISTORY  ACCT_NBR  \
# 0         791        2023-01                             0       791
# 1         791        2023-02                             0       791
#
#   start_date   end_date
# 0 2022-09-01 2023-08-01
# 1 2022-09-01 2023-08-01

# %%
BSI_CreditReporting_yesclosedate_1['CREDIT_BUREAU_PAYMENT_HISTORY'] = np.where(BSI_CreditReporting_yesclosedate_1['CREDIT_BUREAU_PAYMENT_HISTORY'].isin(['B','D','.',0,1,2,3,4,5,6,'H']),BSI_CreditReporting_yesclosedate_1['CREDIT_BUREAU_PAYMENT_HISTORY'],0)
BSI_CreditReporting_yesclosedate_1
# Out:
#          LoanNumber Year_Month_Obs CREDIT_BUREAU_PAYMENT_HISTORY    ACCT_NBR  \
# 0               791        2023-01                             0         791
# 1               791        2023-02                             0         791
# 2               791        2023-03                             0         791
# 3               791        2023-04                             0         791
# 4               791        2023-05                             0         791
# ...             ...            ...                           ...         ...
# 6291931  9119021467        2021-08                             0  9119021467
# 6291932  9119021467        2021-09                             0  9119021467
# 6291933  9119021467        2021-10                             0  9119021467
# 6291934  9119021467        2021-11                             0  9119021467
# 6291935  9119021467        2021-12                             0  9119021467
#
#         start_date   end_date
# 0       2022-09-01 2023-08-01
# 1       2022-09-01 2023-08-01
# 2       2022-09-01 2023-08-01
# 3       2022-09-01 2023-08-01
# 4       2022-09-01 2023-08-01
# ...            ...        ...
# 6291931 2022-09-01 2023-08-01
# 6291932 2022-09-01 2023-08-01
# 6291933 2022-09-01 2023-08-01
# 6291934 2022-09-01 2023-08-01
# 6291935 2022-09-01 2023-08-01
#
# [6291936 rows x 6 columns]

# %%
BSI_CreditReporting_yesclosedate_1['ymo'] = BSI_CreditReporting_yesclosedate_1['Year_Month_Obs'].apply(lambda x: dt.strptime(x, '%Y-%m'))
# Filtering data on the basis of start and end date comparing with ymo
BSI_CreditReporting_yesclosedate_1_ = BSI_CreditReporting_yesclosedate_1[BSI_CreditReporting_yesclosedate_1['ymo'] >= BSI_CreditReporting_yesclosedate_1['start_date']]
BSI_CreditReporting_yesclosedate_1_ = BSI_CreditReporting_yesclosedate_1_[BSI_CreditReporting_yesclosedate_1_['ymo'] <=BSI_CreditReporting_yesclosedate_1_['end_date']]
 
# Removing timestamp from CREDIT_BUREAU_PAYMENT_HISTORY feature
BSI_CreditReporting_yesclosedate_1_['CREDIT_BUREAU_PAYMENT_HISTORY'] = np.where(BSI_CreditReporting_yesclosedate_1_['CREDIT_BUREAU_PAYMENT_HISTORY'].isin(['B','D','.',0,1,2,3,4,5,6,'H']),BSI_CreditReporting_yesclosedate_1_['CREDIT_BUREAU_PAYMENT_HISTORY'],0)
 
# Convert 0 if CBH belongs to categories like (B, D, 0, .) else 1
BSI_CreditReporting_yesclosedate_1_['CBH'] = np.where(BSI_CreditReporting_yesclosedate_1_['CREDIT_BUREAU_PAYMENT_HISTORY'].isin(['B','D','.',0]),0,1)
 
print(BSI_CreditReporting_yesclosedate_1_.shape)
BSI_CreditReporting_yesclosedate_1_.head(2)
# Out:
# (2095761, 8)
#    LoanNumber Year_Month_Obs CREDIT_BUREAU_PAYMENT_HISTORY  ACCT_NBR  \
# 0         791        2023-01                             0       791
# 1         791        2023-02                             0       791
#
#   start_date   end_date        ymo  CBH
# 0 2022-09-01 2023-08-01 2023-01-01    0
# 1 2022-09-01 2023-08-01 2023-02-01    0

# %%
BSI_CreditReporting_yesclosedate_1_['LoanNumber'].value_counts()
# Out:
# LoanNumber
# 791           12
# 1401578744    12
# 1401578443    12
# 1401578516    12
# 1401578519    12
#               ..
# 1201453355    11
# 1218464282    11
# 1401206499    11
# 670163213     11
# 1201440629    11
# Name: count, Length: 174776, dtype: int64

# %%
BSI_CreditReporting_yesclosedate_1_[BSI_CreditReporting_yesclosedate_1_['LoanNumber']==1218464282]
# Out:
#          LoanNumber Year_Month_Obs CREDIT_BUREAU_PAYMENT_HISTORY    ACCT_NBR  \
# 1213440  1218464282        2021-01                             .  1218464282
# 1213441  1218464282        2021-02                             .  1218464282
# 1213442  1218464282        2021-03                             .  1218464282
# 1213443  1218464282        2021-04                             .  1218464282
# 1213444  1218464282        2021-05                             .  1218464282
# 1213445  1218464282        2021-06                             .  1218464282
# 1213446  1218464282        2021-07                             .  1218464282
# 1213447  1218464282        2021-08                             .  1218464282
# 1213448  1218464282        2021-09                             .  1218464282
# 1213449  1218464282        2021-10                             B  1218464282
# 1213450  1218464282        2021-11                             0  1218464282
#
#         start_date   end_date        ymo  CBH
# 1213440 2020-12-01 2021-11-01 2021-01-01    0
# 1213441 2020-12-01 2021-11-01 2021-02-01    0
# 1213442 2020-12-01 2021-11-01 2021-03-01    0
# 1213443 2020-12-01 2021-11-01 2021-04-01    0
# 1213444 2020-12-01 2021-11-01 2021-05-01    0
# 1213445 2020-12-01 2021-11-01 2021-06-01    0
# 1213446 2020-12-01 2021-11-01 2021-07-01    0
# 1213447 2020-12-01 2021-11-01 2021-08-01    0
# 1213448 2020-12-01 2021-11-01 2021-09-01    0
# 1213449 2020-12-01 2021-11-01 2021-10-01    0
# 1213450 2020-12-01 2021-11-01 2021-11-01    0

# %%
BSI_CreditReporting_yesclosedate_final = BSI_CreditReporting_yesclosedate_1_[['LoanNumber','CBH']]
BSI_CreditReporting_yesclosedate_final = BSI_CreditReporting_yesclosedate_final.groupby('LoanNumber').sum('CBH')
#BSI_CreditReporting_yesclosedate_final.rename(columns = {'dummy':'CREDIT_BUREAU_PAYMENT_HISTORY'}, inplace=True)
BSI_CreditReporting_yesclosedate_final = BSI_CreditReporting_yesclosedate_final.reset_index()
BSI_CreditReporting_yesclosedate_final.head()
# Out:
#    LoanNumber  CBH
# 0         791    0
# 1        1235    3
# 2        1262    0
# 3        1571    0
# 4        1596    0

# %%
print(McK_Oneoff.shape)
print(BSI_CreditReporting_yesclosedate_final.shape)
McK_Oneoff_CBH = McK_Oneoff.merge(BSI_CreditReporting_yesclosedate_final,how='left',on = 'LoanNumber')
print(McK_Oneoff_CBH.shape)
McK_Oneoff_CBH.head()
# Out:
# (164246, 44)
# (174776, 2)
# (164246, 45)
#    LoanNumber      LoanType  PrincipalBalance NextDueDate InterestPaidToDate  \
# 0         791  CONVENTIONAL          69477.71  2023-10-01         2023-09-01
# 1        1235  CONVENTIONAL          53245.69  2023-08-01         2023-07-01
# 2        1262  CONVENTIONAL         138728.50  2023-09-01         2023-08-01
# 3        1378  CONVENTIONAL         122249.50  2013-07-01         2013-06-01
# 4        1571  CONVENTIONAL          37677.01  2023-09-01         2023-08-01
#
#   DateLastPayment  InterestRate  OriginalInterestRate PropertyCityName  \
# 0      2023-08-01         2.750                 2.750   NORTH WILDWOOD
# 1      2023-07-28         2.875                 2.875            ASTON
# 2      2023-08-01         2.875                 2.875     PHILADELPHIA
# 3      2013-06-07         4.875                 4.875       LINDENWOLD
# 4      2023-08-04         3.500                 3.500      UPPER DARBY
#
#   PropertyState PropertyZipCode   MailingCity MailingState MailingZip  \
# 0            NJ           08260  SICKLERVILLE           NJ      08081
# 1            PA           19014         ASTON           PA      19014
# 2            PA           19106  PHILADELPHIA           PA      19106
# 3            NJ           08021    LINDENWOLD           NJ      08021
# 4            PA           19082   UPPER DARBY           PA      19082
#
#    FICO_Score    FicoDate BankruptcyFlag LossMitigationStatus  \
# 0       777.0  2023-01-31           None
# 1       608.0  2023-01-31           None
# 2       758.0  2023-01-31           None
# 3       503.0  2016-10-20              C                    C
# 4       801.0  2023-01-31           None
#
#   ForeclosureStatus DLQ_Status    NoteDate ServicingDate TransferDate  \
# 0              None    CURRENT  2013-03-29    2013-04-19   2013-04-24
# 1              None       1-29  2013-03-15    2013-04-05   2013-04-09
# 2              None    CURRENT  2013-05-15    2013-06-14   2013-06-21
# 3                 A        REO  2013-04-05    2013-04-26   2013-04-30
# 4              None    CURRENT  2013-05-03    2013-05-24   2013-05-29
#
#      PiPmt  EscrowPayment  EscrowBalance ReportToCreditBureau AppraisalDate  \
# 0  1425.11           0.00           0.00                    Y    2013-02-01
# 1  1002.92         696.66          19.31                    Y    2013-02-01
# 2  2823.92         422.27        2955.93                    Y    2013-03-01
# 3   647.75         754.16      -56930.34                    N    2013-03-01
# 4   718.46         324.03         626.03                    Y    2013-04-01
#
#    AppraisedAmount  Original_Ltv_Calc  CurrentLTV      PriorServicerName  \
# 0         315000.0              66.67       22.06  ALLIED MORTGAGE GROUP
# 1         232000.0              63.15       22.95  ALLIED MORTGAGE GROUP
# 2         550000.0              75.00       25.22  ALLIED MORTGAGE GROUP
# 3         153000.0              80.00       79.90  ALLIED MORTGAGE GROUP
# 4         104000.0              96.63       36.23  ALLIED MORTGAGE GROUP
#
#      InvestorOwner AcquiredPortfolioName PrimaryBorrowerOptOut  \
# 0    Balbec Fund V     ALLIED [2 - FNMA]                     0
# 1  Balbec Fund III     ALLIED [1 - FNMA]                     0
# 2  Balbec Fund III     ALLIED [1 - FNMA]                     0
# 3             None                  None                     0
# 4  Balbec Fund III     ALLIED [1 - FNMA]                     0
#
#   SecondaryBorrowerOptOut  TermOfLoan  RemainingTerm FIXED ARM  SaleAmount  \
# 0                       0         180             55     FIXED         0.0
# 1                       0         180             57     FIXED         0.0
# 2                       0         180             58     FIXED    550000.0
# 3                       0         360            359     FIXED         0.0
# 4                       0         180             57     FIXED    104000.0
#
#    OriginalBalance RawLeadType ForbearanceFlag Year_Month_Obs  CBH
# 0         210000.0      Allied            None     2023-08-01  0.0
# 1         146500.0      Allied            None     2023-08-01  3.0
# 2         412500.0      Allied            None     2023-08-01  0.0
# 3         122400.0      Allied            None     2023-08-01  NaN
# 4         100500.0      Allied            None     2023-08-01  0.0

# %%
McK_Oneoff_CBH["CBH"].isna().sum()
# Out:
# 1639

# %%
Training_Oneoff=McK_Oneoff_CBH.merge(Avg_interest_rate, how='left',left_on=['LoanNumber'],right_on=['LoanNumber'])

# %%
Training_Oneoff.shape
# Out:
# (164246, 53)

# %%
Training_Oneoff.head(1)
# Out:
#    LoanNumber    LoanType_x  PrincipalBalance NextDueDate InterestPaidToDate  \
# 0         791  CONVENTIONAL          69477.71  2023-10-01         2023-09-01
#
#   DateLastPayment  InterestRate  OriginalInterestRate PropertyCityName  \
# 0      2023-08-01          2.75                  2.75   NORTH WILDWOOD
#
#   PropertyState PropertyZipCode   MailingCity MailingState MailingZip  \
# 0            NJ           08260  SICKLERVILLE           NJ      08081
#
#    FICO_Score    FicoDate BankruptcyFlag LossMitigationStatus  \
# 0       777.0  2023-01-31           None
#
#   ForeclosureStatus DLQ_Status    NoteDate ServicingDate TransferDate  \
# 0              None    CURRENT  2013-03-29    2013-04-19   2013-04-24
#
#      PiPmt  EscrowPayment  EscrowBalance ReportToCreditBureau AppraisalDate  \
# 0  1425.11            0.0            0.0                    Y    2013-02-01
#
#    AppraisedAmount  Original_Ltv_Calc  CurrentLTV      PriorServicerName  \
# 0         315000.0              66.67       22.06  ALLIED MORTGAGE GROUP
#
#    InvestorOwner AcquiredPortfolioName PrimaryBorrowerOptOut  \
# 0  Balbec Fund V     ALLIED [2 - FNMA]                     0
#
#   SecondaryBorrowerOptOut  TermOfLoan  RemainingTerm FIXED ARM  SaleAmount  \
# 0                       0         180             55     FIXED         0.0
#
#    OriginalBalance RawLeadType ForbearanceFlag Year_Month_Obs  CBH  \
# 0         210000.0      Allied            None     2023-08-01  0.0
#
#    Unnamed: 0    LoanType_y  Year  Month  Term   FICO   LTV  \
# 0           0  CONVENTIONAL  2023      6    15  >=760  <=30
#
#    Orginal_Interest_Rate
# 0                 6.6275

# %%
Training_Oneoff.columns.tolist()
# Out:
# ['LoanNumber',
#  'LoanType_x',
#  'PrincipalBalance',
#  'NextDueDate',
#  'InterestPaidToDate',
#  'DateLastPayment',
#  'InterestRate',
#  'OriginalInterestRate',
#  'PropertyCityName',
#  'PropertyState',
#  'PropertyZipCode',
#  'MailingCity',
#  'MailingState',
#  'MailingZip',
#  'FICO_Score',
#  'FicoDate',
#  'BankruptcyFlag',
#  'LossMitigationStatus',
#  'ForeclosureStatus',
#  'DLQ_Status',
#  'NoteDate',
#  'ServicingDate',
#  'TransferDate',
#  'PiPmt',
#  'EscrowPayment',
#  'EscrowBalance',
#  'ReportToCreditBureau',
#  'AppraisalDate',
#  'AppraisedAmount',
#  'Original_Ltv_Calc',
#  'CurrentLTV',
#  'PriorServicerName',
#  'InvestorOwner',
#  'AcquiredPortfolioName',
#  'PrimaryBorrowerOptOut',
#  'SecondaryBorrowerOptOut',
#  'TermOfLoan',
#  'RemainingTerm',
#  'FIXED ARM',
#  'SaleAmount',
#  'OriginalBalance',
#  'RawLeadType',
#  'ForbearanceFlag',
#  'Year_Month_Obs',
#  'CBH',
#  'Unnamed: 0',
#  'LoanType_y',
#  'Year',
#  'Month',
#  'Term',
#  'FICO',
#  'LTV',
#  'Orginal_Interest_Rate']

# %%
Training_Oneoff["LoanType_x"].isna().sum()
# Out:
# 1

# %%
Training_Oneoff["LoanType_y"].isna().sum()
# Out:
# 0

# %%
cols=[
 'LoanNumber',
 'LoanType_y',
#  'LoanType_x',
 'PrincipalBalance',
 'NextDueDate',
 'InterestPaidToDate',
 'DateLastPayment',
 'InterestRate',
 'OriginalInterestRate',
 'PropertyCityName',
 'PropertyState',
 'PropertyZipCode',
 'MailingCity',
 'MailingState',
 'MailingZip',
 'FICO_Score',
 'FicoDate',
 'BankruptcyFlag',
 'LossMitigationStatus',
 'ForeclosureStatus',
 'DLQ_Status',
 'NoteDate',
 'ServicingDate',
 'TransferDate',
 'PiPmt',
 'EscrowPayment',
 'EscrowBalance',
 'ReportToCreditBureau',
 'AppraisalDate',
 'AppraisedAmount',
 'Original_Ltv_Calc',
 'CurrentLTV',
 'PriorServicerName',
 'InvestorOwner',
 'AcquiredPortfolioName',
 'PrimaryBorrowerOptOut',
 'SecondaryBorrowerOptOut',
 'TermOfLoan',
 'RemainingTerm',
 'FIXED ARM',
 'SaleAmount',
 'OriginalBalance',
 'RawLeadType',
 'ForbearanceFlag',
 'Year_Month_Obs',
 'CBH',
 'Orginal_Interest_Rate',
#  'Unnamed: 0',
 'Year',
 'Month',
 'Term',
 'FICO',
 'LTV',  
]

# %%
Training_Oneoff=Training_Oneoff[cols]

# %%
Training_Oneoff.rename({'LoanType_y':'LoanType'},axis=1, inplace=True)

# %%
Training_Oneoff.head(1)
# Out:
#    LoanNumber      LoanType  PrincipalBalance NextDueDate InterestPaidToDate  \
# 0         791  CONVENTIONAL          69477.71  2023-10-01         2023-09-01
#
#   DateLastPayment  InterestRate  OriginalInterestRate PropertyCityName  \
# 0      2023-08-01          2.75                  2.75   NORTH WILDWOOD
#
#   PropertyState PropertyZipCode   MailingCity MailingState MailingZip  \
# 0            NJ           08260  SICKLERVILLE           NJ      08081
#
#    FICO_Score    FicoDate BankruptcyFlag LossMitigationStatus  \
# 0       777.0  2023-01-31           None
#
#   ForeclosureStatus DLQ_Status    NoteDate ServicingDate TransferDate  \
# 0              None    CURRENT  2013-03-29    2013-04-19   2013-04-24
#
#      PiPmt  EscrowPayment  EscrowBalance ReportToCreditBureau AppraisalDate  \
# 0  1425.11            0.0            0.0                    Y    2013-02-01
#
#    AppraisedAmount  Original_Ltv_Calc  CurrentLTV      PriorServicerName  \
# 0         315000.0              66.67       22.06  ALLIED MORTGAGE GROUP
#
#    InvestorOwner AcquiredPortfolioName PrimaryBorrowerOptOut  \
# 0  Balbec Fund V     ALLIED [2 - FNMA]                     0
#
#   SecondaryBorrowerOptOut  TermOfLoan  RemainingTerm FIXED ARM  SaleAmount  \
# 0                       0         180             55     FIXED         0.0
#
#    OriginalBalance RawLeadType ForbearanceFlag Year_Month_Obs  CBH  \
# 0         210000.0      Allied            None     2023-08-01  0.0
#
#    Orginal_Interest_Rate  Year  Month  Term   FICO   LTV
# 0                 6.6275  2023      6    15  >=760  <=30

# %%
Logins = rename_and_transform_logins_columns(BSI_dataframes['Logins'])
display(Logins.head())
# Out:
# >>>>> Logins columns renamed and transformed <<<<<<
#    LoanNumberPlain               LoginDate Login_Year_Month
# 0             1119 2021-02-26 13:22:54.343          2021-02
# 1             1119 2021-02-28 14:17:27.033          2021-02
# 2             1119 2021-11-30 10:54:51.877          2021-11
# 3             1119 2022-02-22 18:14:32.110          2022-02
# 4             1119 2022-06-26 13:35:29.967          2022-06

# %%
Monthly_Login_Count = count_monthly_logins(Logins)
display(Monthly_Login_Count)
# Out:
# >>>>> Monthly Login Count Generated <<<<<<
#          LoanNumberPlain Login_Year_Month  Login_Count
# 0            -2145945248          2022-09            1
# 1            -2145945248          2023-05            1
# 2            -2145945215          2022-08            4
# 3            -2145945215          2022-09            8
# 4            -2145945215          2022-10            5
# ...                  ...              ...          ...
# 1666652       2140630000          2023-04            1
# 1666653       2140630000          2023-05            1
# 1666654       2140630000          2023-06            1
# 1666655       2140630000          2023-07            2
# 1666656       2140630000          2023-09            2
#
# [1666657 rows x 3 columns]

# %%
McK_Oneoff.dtypes
# Out:
# LoanNumber                          int64
# LoanType                           object
# PrincipalBalance                  float64
# NextDueDate                        object
# InterestPaidToDate                 object
# DateLastPayment                    object
# InterestRate                      float64
# OriginalInterestRate              float64
# PropertyCityName                   object
# PropertyState                      object
# PropertyZipCode                    object
# MailingCity                        object
# MailingState                       object
# MailingZip                         object
# FICO_Score                        float64
# FicoDate                           object
# BankruptcyFlag                     object
# LossMitigationStatus               object
# ForeclosureStatus                  object
# DLQ_Status                         object
# NoteDate                           object
# ServicingDate                      object
# TransferDate                       object
# PiPmt                             float64
# EscrowPayment                     float64
# EscrowBalance                     float64
# ReportToCreditBureau               object
# AppraisalDate                      object
# AppraisedAmount                   float64
# Original_Ltv_Calc                 float64
# CurrentLTV                        float64
# PriorServicerName                  object
# InvestorOwner                      object
# AcquiredPortfolioName              object
# PrimaryBorrowerOptOut              object
# SecondaryBorrowerOptOut            object
# TermOfLoan                          int64
# RemainingTerm                       int64
# FIXED ARM                          object
# SaleAmount                        float64
# OriginalBalance                   float64
# RawLeadType                        object
# ForbearanceFlag                    object
# Year_Month_Obs             datetime64[ns]
# dtype: object

# %%
Training_Oneoff["CBH"].dtypes
# Out:
# dtype('float64')

# %%
Training_Oneoff["Orginal_Interest_Rate"].dtypes
# Out:
# dtype('float64')

# %%
Monthly_Login_Count.dtypes
# Out:
# LoanNumberPlain      int64
# Login_Year_Month    object
# Login_Count          int64
# dtype: object

# %%
import re
Monthly_Login_Count['LoanNumberPlain']=Monthly_Login_Count['LoanNumberPlain'].astype(str).str.replace(r'^-','',regex=True)

# %%
display(Monthly_Login_Count)
# Out:
#         LoanNumberPlain Login_Year_Month  Login_Count
# 0            2145945248          2022-09            1
# 1            2145945248          2023-05            1
# 2            2145945215          2022-08            4
# 3            2145945215          2022-09            8
# 4            2145945215          2022-10            5
# ...                 ...              ...          ...
# 1666652      2140630000          2023-04            1
# 1666653      2140630000          2023-05            1
# 1666654      2140630000          2023-06            1
# 1666655      2140630000          2023-07            2
# 1666656      2140630000          2023-09            2
#
# [1666657 rows x 3 columns]

# %%
Column_Data=Monthly_Login_Count['LoanNumberPlain']
for value in Column_Data:
    if'-' in str(value):
        print(value)

# %%
Monthly_Login_Count['LoanNumberPlain']=Monthly_Login_Count["LoanNumberPlain"].astype(int)

# %%
Monthly_Login_Count.dtypes
# Out:
# LoanNumberPlain      int32
# Login_Year_Month    object
# Login_Count          int64
# dtype: object

# %%
Training_Oneoff["Year_Month_Obs"].dtypes
# Out:
# dtype('<M8[ns]')

# %%
Training_Oneoff["Year_Month_Obs"]=Training_Oneoff["Year_Month_Obs"].dt.strftime("%Y-%m")

# %%
Training_Oneoff["Year_Month_Obs"]=Training_Oneoff["Year_Month_Obs"].astype("str")

# %%
Training_Oneoff["Year_Month_Obs"].head(1)
# Out:
# 0    2023-08
# Name: Year_Month_Obs, dtype: object

# %%
Training_Oneoff[['LoanNumber','Year_Month_Obs']].dtypes
# Out:
# LoanNumber         int64
# Year_Month_Obs    object
# dtype: object

# %%
Monthly_Login_Count[['LoanNumberPlain','Login_Year_Month']].dtypes
# Out:
# LoanNumberPlain      int32
# Login_Year_Month    object
# dtype: object

# %%
Monthly_Login_Count[Monthly_Login_Count["LoanNumberPlain"]==791]
# Out:
#         LoanNumberPlain Login_Year_Month  Login_Count
# 155885              791          2021-12            1
# 155886              791          2022-01            4
# 155887              791          2022-03            1

# %%
McK_Oneoff[McK_Oneoff["LoanNumber"]==791]
# Out:
#    LoanNumber      LoanType  PrincipalBalance NextDueDate InterestPaidToDate  \
# 0         791  CONVENTIONAL          69477.71  2023-10-01         2023-09-01
#
#   DateLastPayment  InterestRate  OriginalInterestRate PropertyCityName  \
# 0      2023-08-01          2.75                  2.75   NORTH WILDWOOD
#
#   PropertyState PropertyZipCode   MailingCity MailingState MailingZip  \
# 0            NJ           08260  SICKLERVILLE           NJ      08081
#
#    FICO_Score    FicoDate BankruptcyFlag LossMitigationStatus  \
# 0       777.0  2023-01-31           None
#
#   ForeclosureStatus DLQ_Status    NoteDate ServicingDate TransferDate  \
# 0              None    CURRENT  2013-03-29    2013-04-19   2013-04-24
#
#      PiPmt  EscrowPayment  EscrowBalance ReportToCreditBureau AppraisalDate  \
# 0  1425.11            0.0            0.0                    Y    2013-02-01
#
#    AppraisedAmount  Original_Ltv_Calc  CurrentLTV      PriorServicerName  \
# 0         315000.0              66.67       22.06  ALLIED MORTGAGE GROUP
#
#    InvestorOwner AcquiredPortfolioName PrimaryBorrowerOptOut  \
# 0  Balbec Fund V     ALLIED [2 - FNMA]                     0
#
#   SecondaryBorrowerOptOut  TermOfLoan  RemainingTerm FIXED ARM  SaleAmount  \
# 0                       0         180             55     FIXED         0.0
#
#    OriginalBalance RawLeadType ForbearanceFlag Year_Month_Obs
# 0         210000.0      Allied            None     2023-08-01

# %%
Training_Oneoff_Data = Training_Oneoff.merge(Monthly_Login_Count, how='left',left_on=['LoanNumber','Year_Month_Obs'],right_on=['LoanNumberPlain','Login_Year_Month'])
display(Training_Oneoff_Data.head())
# Out:
#    LoanNumber      LoanType  PrincipalBalance NextDueDate InterestPaidToDate  \
# 0         791  CONVENTIONAL          69477.71  2023-10-01         2023-09-01
# 1        1235  CONVENTIONAL          53245.69  2023-08-01         2023-07-01
# 2        1262  CONVENTIONAL         138728.50  2023-09-01         2023-08-01
# 3        1378  CONVENTIONAL         122249.50  2013-07-01         2013-06-01
# 4        1571  CONVENTIONAL          37677.01  2023-09-01         2023-08-01
#
#   DateLastPayment  InterestRate  OriginalInterestRate PropertyCityName  \
# 0      2023-08-01         2.750                 2.750   NORTH WILDWOOD
# 1      2023-07-28         2.875                 2.875            ASTON
# 2      2023-08-01         2.875                 2.875     PHILADELPHIA
# 3      2013-06-07         4.875                 4.875       LINDENWOLD
# 4      2023-08-04         3.500                 3.500      UPPER DARBY
#
#   PropertyState PropertyZipCode   MailingCity MailingState MailingZip  \
# 0            NJ           08260  SICKLERVILLE           NJ      08081
# 1            PA           19014         ASTON           PA      19014
# 2            PA           19106  PHILADELPHIA           PA      19106
# 3            NJ           08021    LINDENWOLD           NJ      08021
# 4            PA           19082   UPPER DARBY           PA      19082
#
#    FICO_Score    FicoDate BankruptcyFlag LossMitigationStatus  \
# 0       777.0  2023-01-31           None
# 1       608.0  2023-01-31           None
# 2       758.0  2023-01-31           None
# 3       503.0  2016-10-20              C                    C
# 4       801.0  2023-01-31           None
#
#   ForeclosureStatus DLQ_Status    NoteDate ServicingDate TransferDate  \
# 0              None    CURRENT  2013-03-29    2013-04-19   2013-04-24
# 1              None       1-29  2013-03-15    2013-04-05   2013-04-09
# 2              None    CURRENT  2013-05-15    2013-06-14   2013-06-21
# 3                 A        REO  2013-04-05    2013-04-26   2013-04-30
# 4              None    CURRENT  2013-05-03    2013-05-24   2013-05-29
#
#      PiPmt  EscrowPayment  EscrowBalance ReportToCreditBureau AppraisalDate  \
# 0  1425.11           0.00           0.00                    Y    2013-02-01
# 1  1002.92         696.66          19.31                    Y    2013-02-01
# 2  2823.92         422.27        2955.93                    Y    2013-03-01
# 3   647.75         754.16      -56930.34                    N    2013-03-01
# 4   718.46         324.03         626.03                    Y    2013-04-01
#
#    AppraisedAmount  Original_Ltv_Calc  CurrentLTV      PriorServicerName  \
# 0         315000.0              66.67       22.06  ALLIED MORTGAGE GROUP
# 1         232000.0              63.15       22.95  ALLIED MORTGAGE GROUP
# 2         550000.0              75.00       25.22  ALLIED MORTGAGE GROUP
# 3         153000.0              80.00       79.90  ALLIED MORTGAGE GROUP
# 4         104000.0              96.63       36.23  ALLIED MORTGAGE GROUP
#
#      InvestorOwner AcquiredPortfolioName PrimaryBorrowerOptOut  \
# 0    Balbec Fund V     ALLIED [2 - FNMA]                     0
# 1  Balbec Fund III     ALLIED [1 - FNMA]                     0
# 2  Balbec Fund III     ALLIED [1 - FNMA]                     0
# 3             None                  None                     0
# 4  Balbec Fund III     ALLIED [1 - FNMA]                     0
#
#   SecondaryBorrowerOptOut  TermOfLoan  RemainingTerm FIXED ARM  SaleAmount  \
# 0                       0         180             55     FIXED         0.0
# 1                       0         180             57     FIXED         0.0
# 2                       0         180             58     FIXED    550000.0
# 3                       0         360            359     FIXED         0.0
# 4                       0         180             57     FIXED    104000.0
#
#    OriginalBalance RawLeadType ForbearanceFlag Year_Month_Obs  CBH  \
# 0         210000.0      Allied            None        2023-08  0.0
# 1         146500.0      Allied            None        2023-08  3.0
# 2         412500.0      Allied            None        2023-08  0.0
# 3         122400.0      Allied            None        2023-08  NaN
# 4         100500.0      Allied            None        2023-08  0.0
#
#    Orginal_Interest_Rate  Year  Month  Term   FICO   LTV  LoanNumberPlain  \
# 0                 6.6275  2023      6    15  >=760  <=30              NaN
# 1                 6.6275  2023      6    15   <620  <=30              NaN
# 2                 6.6275  2023      6    15  >=740  <=30              NaN
# 3                 6.6275  2023      6    30   <620  <=80              NaN
# 4                 6.6275  2023      6    15  >=780  <=60              NaN
#
#   Login_Year_Month  Login_Count
# 0              NaN          NaN
# 1              NaN          NaN
# 2              NaN          NaN
# 3              NaN          NaN
# 4              NaN          NaN

# %%
Training_Oneoff_Data_Record = add_fips_to_training_oneoff(Training_Oneoff_Data, public_dataframes['Zip_fips_lookup'])
display(Training_Oneoff_Data_Record.head())
# Out:
# >>>>> FIPS Added to McK_Oneoff <<<<<<
#    LoanNumber      LoanType  PrincipalBalance NextDueDate InterestPaidToDate  \
# 0         791  CONVENTIONAL          69477.71  2023-10-01         2023-09-01
# 1        1235  CONVENTIONAL          53245.69  2023-08-01         2023-07-01
# 2        1262  CONVENTIONAL         138728.50  2023-09-01         2023-08-01
# 3        1378  CONVENTIONAL         122249.50  2013-07-01         2013-06-01
# 4        1571  CONVENTIONAL          37677.01  2023-09-01         2023-08-01
#
#   DateLastPayment  InterestRate  OriginalInterestRate PropertyCityName  \
# 0      2023-08-01         2.750                 2.750   NORTH WILDWOOD
# 1      2023-07-28         2.875                 2.875            ASTON
# 2      2023-08-01         2.875                 2.875     PHILADELPHIA
# 3      2013-06-07         4.875                 4.875       LINDENWOLD
# 4      2023-08-04         3.500                 3.500      UPPER DARBY
#
#   PropertyState PropertyZipCode   MailingCity MailingState MailingZip  \
# 0            NJ           08260  SICKLERVILLE           NJ      08081
# 1            PA           19014         ASTON           PA      19014
# 2            PA           19106  PHILADELPHIA           PA      19106
# 3            NJ           08021    LINDENWOLD           NJ      08021
# 4            PA           19082   UPPER DARBY           PA      19082
#
#    FICO_Score    FicoDate BankruptcyFlag LossMitigationStatus  \
# 0       777.0  2023-01-31           None
# 1       608.0  2023-01-31           None
# 2       758.0  2023-01-31           None
# 3       503.0  2016-10-20              C                    C
# 4       801.0  2023-01-31           None
#
#   ForeclosureStatus DLQ_Status    NoteDate ServicingDate TransferDate  \
# 0              None    CURRENT  2013-03-29    2013-04-19   2013-04-24
# 1              None       1-29  2013-03-15    2013-04-05   2013-04-09
# 2              None    CURRENT  2013-05-15    2013-06-14   2013-06-21
# 3                 A        REO  2013-04-05    2013-04-26   2013-04-30
# 4              None    CURRENT  2013-05-03    2013-05-24   2013-05-29
#
#      PiPmt  EscrowPayment  EscrowBalance ReportToCreditBureau AppraisalDate  \
# 0  1425.11           0.00           0.00                    Y    2013-02-01
# 1  1002.92         696.66          19.31                    Y    2013-02-01
# 2  2823.92         422.27        2955.93                    Y    2013-03-01
# 3   647.75         754.16      -56930.34                    N    2013-03-01
# 4   718.46         324.03         626.03                    Y    2013-04-01
#
#    AppraisedAmount  Original_Ltv_Calc  CurrentLTV      PriorServicerName  \
# 0         315000.0              66.67       22.06  ALLIED MORTGAGE GROUP
# 1         232000.0              63.15       22.95  ALLIED MORTGAGE GROUP
# 2         550000.0              75.00       25.22  ALLIED MORTGAGE GROUP
# 3         153000.0              80.00       79.90  ALLIED MORTGAGE GROUP
# 4         104000.0              96.63       36.23  ALLIED MORTGAGE GROUP
#
#      InvestorOwner AcquiredPortfolioName PrimaryBorrowerOptOut  \
# 0    Balbec Fund V     ALLIED [2 - FNMA]                     0
# 1  Balbec Fund III     ALLIED [1 - FNMA]                     0
# 2  Balbec Fund III     ALLIED [1 - FNMA]                     0
# 3             None                  None                     0
# 4  Balbec Fund III     ALLIED [1 - FNMA]                     0
#
#   SecondaryBorrowerOptOut  TermOfLoan  RemainingTerm FIXED ARM  SaleAmount  \
# 0                       0         180             55     FIXED         0.0
# 1                       0         180             57     FIXED         0.0
# 2                       0         180             58     FIXED    550000.0
# 3                       0         360            359     FIXED         0.0
# 4                       0         180             57     FIXED    104000.0
#
#    OriginalBalance RawLeadType ForbearanceFlag Year_Month_Obs  CBH  \
# 0         210000.0      Allied            None        2023-08  0.0
# 1         146500.0      Allied            None        2023-08  3.0
# 2         412500.0      Allied            None        2023-08  0.0
# 3         122400.0      Allied            None        2023-08  NaN
# 4         100500.0      Allied            None        2023-08  0.0
#
#    Orginal_Interest_Rate  Year  Month  Term   FICO   LTV  LoanNumberPlain  \
# 0                 6.6275  2023      6    15  >=760  <=30              NaN
# 1                 6.6275  2023      6    15   <620  <=30              NaN
# 2                 6.6275  2023      6    15  >=740  <=30              NaN
# 3                 6.6275  2023      6    30   <620  <=80              NaN
# 4                 6.6275  2023      6    15  >=780  <=60              NaN
#
#   Login_Year_Month  Login_Count     FIPS
# 0              NaN          NaN  34009.0
# 1              NaN          NaN  42045.0
# 2              NaN          NaN  42101.0
# 3              NaN          NaN  34007.0
# 4              NaN          NaN  42045.0

# %%
Training_Oneoff_Data_Record.shape
# Out:
# (164246, 55)

# %%
Training_Oneoff_Data_Record["CBH"].isna().sum()
# Out:
# 1639

# %%
Demographic = clean_domographic(public_dataframes['Demographic'])
display(Demographic.head())
# Out:
#                            code  geography  \
# 0   Shiawassee County, Michigan    26155.0
# 1    Washtenaw County, Michigan    26161.0
# 2       Scott County, Minnesota    27139.0
# 3      Wright County, Minnesota    27171.0
# 4  Harrison County, Mississippi    28047.0
#
#    Percent_EDUCATIONAL_ATTAINMENT_Population_25_years_and_over_Bachelors_degree_or_higher  \
# 0                                               19.0
# 1                                               57.3
# 2                                               45.3
# 3                                               34.9
# 4                                               27.9
#
#    Percent_VEHICLES_AVAILABLE_Occupied_housing_units_No_vehicles_available  \
# 0                                                4.7
# 1                                                7.5
# 2                                                3.3
# 3                                                2.0
# 4                                                4.6
#
#    Percent_VEHICLES_AVAILABLE_Occupied_housing_units_1_vehicle_available  \
# 0                                               31.9
# 1                                               36.9
# 2                                               21.4
# 3                                               21.4
# 4                                               31.7
#
#    Percent_VEHICLES_AVAILABLE_Occupied_housing_units_3_or_more_vehicles_available  \
# 0                                               22.1
# 1                                               18.2
# 2                                               26.6
# 3                                               33.7
# 4                                               22.8
#
#    Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Agriculture_forestry_fishing_and_hunting_and_mining  \
# 0                                                1.3
# 1                                                0.9
# 2                                                0.6
# 3                                                2.7
# 4                                                0.8
#
#    Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Construction  \
# 0                                                5.9
# 1                                                3.4
# 2                                                8.9
# 3                                               10.6
# 4                                                7.2
#
#    Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Manufacturing  \
# 0                                               22.6
# 1                                               13.2
# 2                                               16.1
# 3                                               14.8
# 4                                                5.7
#
#    Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Wholesale_trade  \
# 0                                                1.4
# 1                                                1.2
# 2                                                3.1
# 3                                                4.5
# 4                                                2.2
#
#    Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Retail_trade  \
# 0                                               11.8
# 1                                                8.8
# 2                                               13.1
# 3                                               11.6
# 4                                               11.1
#
#    Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Transportation_and_warehousing_and_utilities  \
# 0                                                5.6
# 1                                                2.8
# 2                                                4.5
# 3                                                3.2
# 4                                                5.6
#
#    Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Information  \
# 0                                                1.1
# 1                                                1.4
# 2                                                0.8
# 3                                                0.4
# 4                                                1.5
#
#    Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Finance_and_insurance_and_real_estate_and_rental_and_leasing  \
# 0                                                4.5
# 1                                                3.5
# 2                                                9.6
# 3                                                7.4
# 4                                                4.9
#
#    Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Professional_scientific_and_management_and_administrative_and_waste_management_services  \
# 0                                                7.0
# 1                                               13.8
# 2                                               10.9
# 3                                                8.6
# 4                                                7.0
#
#    Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Educational_services_and_health_care_and_social_assistance  \
# 0                                               22.2
# 1                                               36.6
# 2                                               19.9
# 3                                               21.1
# 4                                               26.5
#
#    Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Arts_entertainment_and_recreation_and_accommodation_and_food_services  \
# 0                                                7.2
# 1                                                7.5
# 2                                                6.3
# 3                                                6.9
# 4                                               14.8
#
#    Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Other_services_except_public_administration  \
# 0                                                5.3
# 1                                                4.4
# 2                                                3.5
# 3                                                5.2
# 4                                                4.8
#
#    Percent_INDUSTRY_Civilian_employed_population_16_years_and_over_Public_administration  \
# 0                                                4.1
# 1                                                2.6
# 2                                                2.8
# 3                                                3.1
# 4                                                7.9
#
#    Percent_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_earnings  \
# 0                                               70.0
# 1                                               81.4
# 2                                               86.9
# 3                                               84.6
# 4                                               73.5
#
#    Percent_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_Social_Security  \
# 0                                               35.6
# 1                                               27.1
# 2                                               20.5
# 3                                               27.6
# 4                                               35.9
#
#    Percent_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_retirement_income  \
# 0                                               29.1
# 1                                               24.8
# 2                                               17.6
# 3                                               20.4
# 4                                               27.1
#
#    Percent_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_Supplemental_Security_Income  \
# 0                                                4.8
# 1                                                3.2
# 2                                                2.2
# 3                                                2.3
# 4                                                8.7
#
#    Percent_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_cash_public_assistance_income  \
# 0                                                3.4
# 1                                                3.0
# 2                                                2.5
# 3                                                4.2
# 4                                                2.5
#
#    Percent_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_Food_Stamp_over_SNAP_benefits_in_the_past_12_months  \
# 0                                               13.9
# 1                                                8.0
# 2                                                4.8
# 3                                                4.2
# 4                                               13.2
#
#    Percent_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Nonfamily_households  \
# 0                                            10128.0
# 1                                            64199.0
# 2                                            12424.0
# 3                                            14696.0
# 4                                            26849.0
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_Median_household_income_dollars  \
# 0                                            51959.0
# 1                                            76918.0
# 2                                           106987.0
# 3                                            99964.0
# 4                                            55702.0
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_Mean_household_income_dollars  \
# 0                                            67420.0
# 1                                           110643.0
# 2                                           134003.0
# 3                                           109991.0
# 4                                            71789.0
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_earnings_Mean_earnings_dollars  \
# 0                                            68081.0
# 1                                           106990.0
# 2                                           133971.0
# 3                                           109112.0
# 4                                            69251.0
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_Social_Security_Mean_Social_Security_income_dollars  \
# 0                                            22473.0
# 1                                            25088.0
# 2                                            24039.0
# 3                                            21660.0
# 4                                            18224.0
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_retirement_income_Mean_retirement_income_dollars  \
# 0                                            21692.0
# 1                                            35134.0
# 2                                            33409.0
# 3                                            24937.0
# 4                                            28686.0
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_Supplemental_Security_Income_Mean_Supplemental_Security_Income_dollars  \
# 0                                            11653.0
# 1                                            12604.0
# 2                                            11261.0
# 3                                            15327.0
# 4                                            10473.0
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_cash_public_assistance_income_Mean_cash_public_assistance_income_dollars  \
# 0                                             5663.0
# 1                                             4510.0
# 2                                             4875.0
# 3                                             5653.0
# 4                                             2358.0
#
#    Percent_HEALTH_INSURANCE_COVERAGE_Civilian_noninstitutionalized_population_With_health_insurance_coverage_With_private_health_insurance  \
# 0                                               69.6
# 1                                               81.0
# 2                                               84.3
# 3                                               80.3
# 4                                               62.1
#
#    Percent_HEALTH_INSURANCE_COVERAGE_Civilian_noninstitutionalized_population_With_health_insurance_coverage_With_public_coverage  \
# 0                                               42.8
# 1                                               28.8
# 2                                               22.2
# 3                                               26.7
# 4                                               40.2
#
#    Percent_HEALTH_INSURANCE_COVERAGE_Civilian_noninstitutionalized_population_No_health_insurance_coverage  \
# 0                                                4.2
# 1                                                3.8
# 2                                                3.9
# 3                                                4.1
# 4                                               13.5
#
#    Estimate_EMPLOYMENT_STATUS_Population_16_years_and_over  \
# 0                                            55486.0
# 1                                           310111.0
# 2                                           118377.0
# 3                                           110629.0
# 4                                           166048.0
#
#    Percent_EMPLOYMENT_STATUS_Population_16_years_and_over_In_labor_force  \
# 0                                               58.9
# 1                                               64.0
# 2                                               76.5
# 3                                               71.1
# 4                                               58.5
#
#    Percent_EMPLOYMENT_STATUS_Civilian_labor_force_Unemployment_Rate  \
# 0                                                6.8
# 1                                                4.8
# 2                                                4.0
# 3                                                2.1
# 4                                                8.8
#
#    Percent_SELECTED_MONTHLY_OWNER_COSTS_AS_A_PERCENTAGE_OF_HOUSEHOLD_INCOME_SMOCAPI_Housing_units_with_a_mortgage_excluding_units_where_SMOCAPI_cannot_be_computed_35_0_percent_or_more  \
# 0                                               17.0
# 1                                               15.5
# 2                                               14.3
# 3                                               18.6
# 4                                               23.3
#
#    Percent_SELECTED_MONTHLY_OWNER_COSTS_AS_A_PERCENTAGE_OF_HOUSEHOLD_INCOME_SMOCAPI_Housing_unit_without_a_mortgage_excluding_units_where_SMOCAPI_cannot_be_computed_35_0_percent_or_more  \
# 0                                               10.0
# 1                                                9.8
# 2                                                4.0
# 3                                                5.8
# 4                                                7.9
#
#    Percent_GROSS_RENT_AS_A_PERCENTAGE_OF_HOUSEHOLD_INCOME_GRAPI_Occupied_units_paying_rent_excluding_units_where_GRAPI_cannot_be_computed_35_0_percent_or_more  \
# 0                                               37.7
# 1                                               46.2
# 2                                               38.1
# 3                                               25.9
# 4                                               36.1
#
#    Percent_HOUSING_TENURE_Occupied_housing_units_Owner_occupied  \
# 0                                               77.3
# 1                                               60.6
# 2                                               81.5
# 3                                               81.5
# 4                                               58.9
#
#    Percent_HOUSING_TENURE_Occupied_housing_units_Renter_occupied  \
# 0                                               22.7
# 1                                               39.4
# 2                                               18.5
# 3                                               18.5
# 4                                               41.1
#
#    Percent_HOUSING_OCCUPANCY_Total_housing_units_Vacant_housing_units  \
# 0                                                6.8
# 1                                                5.6
# 2                                                0.4
# 3                                                6.8
# 4                                               13.1
#
#    GINI_index  Estimate_Median_gross_rent_as_a_percentage_of_household_income  \
# 0      0.3969                                               29.1
# 1      0.4892                                               32.9
# 2      0.4094                                               27.2
# 3      0.3584                                               23.1
# 4      0.4589                                               28.9
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_Median_household_income_dollars_1  \
# 0                                              51959
# 1                                              76918
# 2                                             106987
# 3                                              99964
# 4                                              55702
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_Mean_household_income_dollars_1  \
# 0                                              67420
# 1                                             110643
# 2                                             134003
# 3                                             109991
# 4                                              71789
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_earnings_Mean_earnings_dollars_1  \
# 0                                              68081
# 1                                             106990
# 2                                             133971
# 3                                             109112
# 4                                              69251
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_Social_Security_Mean_Social_Security_income_dollars_1  \
# 0                                              22473
# 1                                              25088
# 2                                              24039
# 3                                              21660
# 4                                              18224
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_retirement_income_Mean_retirement_income_dollars_1  \
# 0                                              21692
# 1                                              35134
# 2                                              33409
# 3                                              24937
# 4                                              28686
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_Supplemental_Security_Income_Mean_Supplemental_Security_Income_dollars_1  \
# 0                                              11653
# 1                                              12604
# 2                                              11261
# 3                                              15327
# 4                                              10473
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_cash_public_assistance_income_Mean_cash_public_assistance_income_dollars_1  \
# 0                                               5663
# 1                                               4510
# 2                                               4875
# 3                                               5653
# 4                                               2358
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Families_Median_family_income_dollars  \
# 0                                              66626
# 1                                             110536
# 2                                             115788
# 3                                             108136
# 4                                              64885
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Families_Mean_family_income_dollars  \
# 0                                              79597
# 1                                             145195
# 2                                             148836
# 3                                             122965
# 4                                              83864
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Per_capita_income_dollars  \
# 0                                              28495
# 1                                              46033
# 2                                              48546
# 3                                              39900
# 4                                              28760
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Nonfamily_households_Median_nonfamily_income_dollars  \
# 0                                              36636
# 1                                              45073
# 2                                              64908
# 3                                              55991
# 4                                              32080
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Nonfamily_households_Mean_nonfamily_income_dollars  \
# 0                                              42158
# 1                                              63047
# 2                                              75085
# 3                                              71241
# 4                                              43328
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Median_earnings_for_workers_dollars
# 0                                              36248
# 1                                              37461
# 2                                              52031
# 3                                              49694
# 4                                              32998

# %%
Training_Oneoff_Data_Record=Training_Oneoff_Data_Record.merge(Demographic, how='left',left_on=['FIPS'],right_on=['geography'])
Training_Oneoff_Data_Record=Training_Oneoff_Data_Record.merge(Purchase_index, how='left',left_on=['Year_Month_Obs','PropertyState'],right_on=['Year_Month_Index','state'])
display(Training_Oneoff_Data_Record.head())
print(Training_Oneoff_Data_Record.shape)
# Out:
#    LoanNumber      LoanType  PrincipalBalance NextDueDate InterestPaidToDate  \
# 0         791  CONVENTIONAL          69477.71  2023-10-01         2023-09-01
# 1        1235  CONVENTIONAL          53245.69  2023-08-01         2023-07-01
# 2        1262  CONVENTIONAL         138728.50  2023-09-01         2023-08-01
# 3        1378  CONVENTIONAL         122249.50  2013-07-01         2013-06-01
# 4        1571  CONVENTIONAL          37677.01  2023-09-01         2023-08-01
#
#   DateLastPayment  InterestRate  OriginalInterestRate PropertyCityName  \
# 0      2023-08-01         2.750                 2.750   NORTH WILDWOOD
# 1      2023-07-28         2.875                 2.875            ASTON
# 2      2023-08-01         2.875                 2.875     PHILADELPHIA
# 3      2013-06-07         4.875                 4.875       LINDENWOLD
# 4      2023-08-04         3.500                 3.500      UPPER DARBY
#
#   PropertyState PropertyZipCode   MailingCity MailingState MailingZip  \
# 0            NJ           08260  SICKLERVILLE           NJ      08081
# 1            PA           19014         ASTON           PA      19014
# 2            PA           19106  PHILADELPHIA           PA      19106
# 3            NJ           08021    LINDENWOLD           NJ      08021
# 4            PA           19082   UPPER DARBY           PA      19082
#
#    FICO_Score    FicoDate BankruptcyFlag LossMitigationStatus  \
# 0       777.0  2023-01-31           None
# 1       608.0  2023-01-31           None
# 2       758.0  2023-01-31           None
# 3       503.0  2016-10-20              C                    C
# 4       801.0  2023-01-31           None
#
#   ForeclosureStatus DLQ_Status    NoteDate ServicingDate TransferDate  \
# 0              None    CURRENT  2013-03-29    2013-04-19   2013-04-24
# 1              None       1-29  2013-03-15    2013-04-05   2013-04-09
# 2              None    CURRENT  2013-05-15    2013-06-14   2013-06-21
# 3                 A        REO  2013-04-05    2013-04-26   2013-04-30
# 4              None    CURRENT  2013-05-03    2013-05-24   2013-05-29
#
#      PiPmt  EscrowPayment  EscrowBalance ReportToCreditBureau AppraisalDate  \
# 0  1425.11           0.00           0.00                    Y    2013-02-01
# 1  1002.92         696.66          19.31                    Y    2013-02-01
# 2  2823.92         422.27        2955.93                    Y    2013-03-01
# 3   647.75         754.16      -56930.34                    N    2013-03-01
# 4   718.46         324.03         626.03                    Y    2013-04-01
#
#    AppraisedAmount  Original_Ltv_Calc  CurrentLTV      PriorServicerName  \
# 0         315000.0              66.67       22.06  ALLIED MORTGAGE GROUP
# 1         232000.0              63.15       22.95  ALLIED MORTGAGE GROUP
# 2         550000.0              75.00       25.22  ALLIED MORTGAGE GROUP
# 3         153000.0              80.00       79.90  ALLIED MORTGAGE GROUP
# 4         104000.0              96.63       36.23  ALLIED MORTGAGE GROUP
#
#      InvestorOwner AcquiredPortfolioName PrimaryBorrowerOptOut  ...  \
# 0    Balbec Fund V     ALLIED [2 - FNMA]                     0  ...
# 1  Balbec Fund III     ALLIED [1 - FNMA]                     0  ...
# 2  Balbec Fund III     ALLIED [1 - FNMA]                     0  ...
# 3             None                  None                     0  ...
# 4  Balbec Fund III     ALLIED [1 - FNMA]                     0  ...
#
#   Percent_HEALTH_INSURANCE_COVERAGE_Civilian_noninstitutionalized_population_With_health_insurance_coverage_With_private_health_insurance  \
# 0                                               78.7
# 1                                               78.7
# 2                                               59.3
# 3                                               67.9
# 4                                               78.7
#
#    Percent_HEALTH_INSURANCE_COVERAGE_Civilian_noninstitutionalized_population_With_health_insurance_coverage_With_public_coverage  \
# 0                                               40.8
# 1                                               35.3
# 2                                               45.4
# 3                                               37.6
# 4                                               35.3
#
#    Percent_HEALTH_INSURANCE_COVERAGE_Civilian_noninstitutionalized_population_No_health_insurance_coverage  \
# 0                                                4.9
# 1                                                4.3
# 2                                                7.2
# 3                                                6.3
# 4                                                4.3
#
#   Estimate_EMPLOYMENT_STATUS_Population_16_years_and_over  \
# 0                                            81385.0
# 1                                           459604.0
# 2                                          1270642.0
# 3                                           418498.0
# 4                                           459604.0
#
#    Percent_EMPLOYMENT_STATUS_Population_16_years_and_over_In_labor_force  \
# 0                                               56.6
# 1                                               66.2
# 2                                               62.9
# 3                                               65.6
# 4                                               66.2
#
#    Percent_EMPLOYMENT_STATUS_Civilian_labor_force_Unemployment_Rate  \
# 0                                                6.3
# 1                                                8.6
# 2                                               10.5
# 3                                                8.6
# 4                                                8.6
#
#   Percent_SELECTED_MONTHLY_OWNER_COSTS_AS_A_PERCENTAGE_OF_HOUSEHOLD_INCOME_SMOCAPI_Housing_units_with_a_mortgage_excluding_units_where_SMOCAPI_cannot_be_computed_35_0_percent_or_more  \
# 0                                               26.0
# 1                                               19.5
# 2                                               25.1
# 3                                               21.2
# 4                                               19.5
#
#   Percent_SELECTED_MONTHLY_OWNER_COSTS_AS_A_PERCENTAGE_OF_HOUSEHOLD_INCOME_SMOCAPI_Housing_unit_without_a_mortgage_excluding_units_where_SMOCAPI_cannot_be_computed_35_0_percent_or_more  \
# 0                                               13.9
# 1                                               12.3
# 2                                               16.0
# 3                                               19.3
# 4                                               12.3
#
#   Percent_GROSS_RENT_AS_A_PERCENTAGE_OF_HOUSEHOLD_INCOME_GRAPI_Occupied_units_paying_rent_excluding_units_where_GRAPI_cannot_be_computed_35_0_percent_or_more  \
# 0                                               51.1
# 1                                               47.4
# 2                                               43.6
# 3                                               43.4
# 4                                               47.4
#
#    Percent_HOUSING_TENURE_Occupied_housing_units_Owner_occupied  \
# 0                                               78.1
# 1                                               69.1
# 2                                               52.8
# 3                                               65.3
# 4                                               69.1
#
#    Percent_HOUSING_TENURE_Occupied_housing_units_Renter_occupied  \
# 0                                               21.9
# 1                                               30.9
# 2                                               47.2
# 3                                               34.7
# 4                                               30.9
#
#    Percent_HOUSING_OCCUPANCY_Total_housing_units_Vacant_housing_units  \
# 0                                               50.8
# 1                                                4.8
# 2                                                9.8
# 3                                                5.8
# 4                                                4.8
#
#    GINI_index  Estimate_Median_gross_rent_as_a_percentage_of_household_income  \
# 0      0.4850                                               35.3
# 1      0.4909                                               33.4
# 2      0.5142                                               31.4
# 3      0.4680                                               31.8
# 4      0.4909                                               33.4
#
#   Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_Median_household_income_dollars_1  \
# 0                                            78657.0
# 1                                            78220.0
# 2                                            52899.0
# 3                                            78347.0
# 4                                            78220.0
#
#   Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_Mean_household_income_dollars_1  \
# 0                                           108949.0
# 1                                           114642.0
# 2                                            77734.0
# 3                                           103988.0
# 4                                           114642.0
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_earnings_Mean_earnings_dollars_1  \
# 0                                           100778.0
# 1                                           116543.0
# 2                                            85088.0
# 3                                           105447.0
# 4                                           116543.0
#
#   Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_Social_Security_Mean_Social_Security_income_dollars_1  \
# 0                                            24146.0
# 1                                            23048.0
# 2                                            16958.0
# 3                                            21389.0
# 4                                            23048.0
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_retirement_income_Mean_retirement_income_dollars_1  \
# 0                                            48102.0
# 1                                            27005.0
# 2                                            21463.0
# 3                                            31265.0
# 4                                            27005.0
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_Supplemental_Security_Income_Mean_Supplemental_Security_Income_dollars_1  \
# 0                                            10694.0
# 1                                            10461.0
# 2                                             9571.0
# 3                                            11052.0
# 4                                            10461.0
#
#   Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_With_cash_public_assistance_income_Mean_cash_public_assistance_income_dollars_1  \
# 0                                             3462.0
# 1                                             3839.0
# 2                                             3809.0
# 3                                             6091.0
# 4                                             3839.0
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Families_Median_family_income_dollars  \
# 0                                            92443.0
# 1                                           106291.0
# 2                                            61775.0
# 3                                            99270.0
# 4                                           106291.0
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Families_Mean_family_income_dollars  \
# 0                                           131956.0
# 1                                           140618.0
# 2                                            91456.0
# 3                                           123621.0
# 4                                           140618.0
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Per_capita_income_dollars  \
# 0                                            53482.0
# 1                                            44405.0
# 2                                            32707.0
# 3                                            39948.0
# 4                                            44405.0
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Nonfamily_households_Median_nonfamily_income_dollars  \
# 0                                            47500.0
# 1                                            45436.0
# 2                                            37802.0
# 3                                            46482.0
# 4                                            45436.0
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Nonfamily_households_Mean_nonfamily_income_dollars  \
# 0                                            61664.0
# 1                                            64018.0
# 2                                            58421.0
# 3                                            61107.0
# 4                                            64018.0
#
#    Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Median_earnings_for_workers_dollars  \
# 0                                            49664.0
# 1                                            45285.0
# 2                                            39068.0
# 3                                            43973.0
# 4                                            45285.0
#
#    state  yr  qtr  index_nsa  index_sa  Year_Month_Index  Index_delta_4Qs_nsa  \
# 0    NaN NaN  NaN        NaN       NaN               NaN                  NaN
# 1    NaN NaN  NaN        NaN       NaN               NaN                  NaN
# 2    NaN NaN  NaN        NaN       NaN               NaN                  NaN
# 3    NaN NaN  NaN        NaN       NaN               NaN                  NaN
# 4    NaN NaN  NaN        NaN       NaN               NaN                  NaN
#
#    Index_delta_4Qs_sa
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 123 columns]
# (164246, 123)

# %%
Training_Oneoff_Data_Record["CBH"]
# Out:
# 0         0.0
# 1         3.0
# 2         0.0
# 3         NaN
# 4         0.0
#          ...
# 164241    0.0
# 164242    NaN
# 164243    NaN
# 164244    0.0
# 164245    0.0
# Name: CBH, Length: 164246, dtype: float64

# %%
Training_Oneoff_Data_Record["Orginal_Interest_Rate"]
# Out:
# 0         6.6275
# 1         6.6275
# 2         6.6275
# 3         6.6275
# 4         6.6275
#            ...
# 164241    6.6275
# 164242    6.6275
# 164243    6.6275
# 164244    6.6275
# 164245    6.6275
# Name: Orginal_Interest_Rate, Length: 164246, dtype: float64

# %%
Training_Oneoff_Data_Record.rename(columns = {'CBH':'CREDIT_BUREAU_PAYMENT_HISTORY'}, inplace = True)

# %%
Training_Oneoff_Data_Record["CREDIT_BUREAU_PAYMENT_HISTORY"].isna().sum()
# Out:
# 1639

# %%
# Transformation a New Features for used the Model Training

Training_Oneoff_Data_Record['Is_MailingZip_Equal_PropZip']=(Training_Oneoff_Data_Record['PropertyZipCode'].
                                                            astype(str)==Training_Oneoff_Data_Record['MailingZip'].
                                                            astype(str).apply(lambda x: x[:6])).astype(int)

Training_Oneoff_Data_Record['Interest_Delta_Current_Orginal']=(Training_Oneoff_Data_Record['InterestRate']-
                                                               Training_Oneoff_Data_Record['OriginalInterestRate']) # This features not used in model training, just for analysis to check.

Training_Oneoff_Data_Record['Interest_Delta_Current_Market']=(Training_Oneoff_Data_Record['InterestRate']-
                                             Training_Oneoff_Data_Record['Orginal_Interest_Rate'])

Training_Oneoff_Data_Record['Ltv_Delta_Orginal_Current']=(Training_Oneoff_Data_Record['Original_Ltv_Calc']-
                                         Training_Oneoff_Data_Record['CurrentLTV'])

Training_Oneoff_Data_Record['CREDIT_BUREAU_PAYMENT_HISTORY']=Training_Oneoff_Data_Record['CREDIT_BUREAU_PAYMENT_HISTORY'].fillna(0)

# %%
# Shape Check

Training_Oneoff_Data_Record.shape
# Out:
# (164246, 127)

# %%
# Select the model training feature

Training_Oneoff_Data_Record=Training_Oneoff_Data_Record[["LoanNumber","LoanType","CREDIT_BUREAU_PAYMENT_HISTORY",
                                                        "PrincipalBalance","Is_MailingZip_Equal_PropZip","FICO_Score",
                                                        "CurrentLTV","Login_Count","Interest_Delta_Current_Market",
                                                         "Ltv_Delta_Orginal_Current",
                                                         "Percent_EDUCATIONAL_ATTAINMENT_Population_25_years_and_over_Bachelors_degree_or_higher",
                                                        "Estimate_INCOME_AND_BENEFITS_IN_2021_INFLATION_ADJUSTED_DOLLARS_Total_households_Mean_household_income_dollars",
                                                        "Percent_HOUSING_TENURE_Occupied_housing_units_Owner_occupied"]]

# %%
# Model Training Data

Training_Oneoff_Data_Record.to_csv("Incedo Transition Folder/1-Data Source/Training Data/Output_Data/BSI_One_Year_Training_Data.csv",index=False)

# %% [markdown]
# #### Completed Data Merging Below Files
# 1- MCK_ONE_OFF
#
# 2- Interest_Rate(New)
#
# 3- BSI Credit Reporting (New)
#
# 4- Census_Demographics
#
# 5- HPI
#
# 6- ZIP_SIPS
#
# 7- MLW_LOGINS

# %% [markdown]
# ### Important Points
#
# This code file generated the BSI_one_Year_Training_Data, THis data save in "Incedo Transition Folder/1-Data Source/Training Data/Output_Data/BSI_One_Year_Training_Data.csv"

# %% [markdown]
# ## Completed
